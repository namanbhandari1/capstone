# %% [markdown]
# # 5. Find Cosine Similarity

# %% [markdown]
# ## Load Files

# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity

import pickle
import time

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open ('../pickles/df.pkl', 'rb') as pkl:
    df = pickle.load(pkl)

# %%
with open ('../pickles/ben_cols.pkl', 'rb') as pkl:
    ben_cols = pickle.load(pkl)
    
with open ('../pickles/ben_cols_dum.pkl', 'rb') as pkl:
    ben_cols_dum = pickle.load(pkl)

# %%
with open ('../pickles/rate_cols.pkl', 'rb') as pkl:
    rate_cols = pickle.load(pkl)

# %%
list(df.columns)
# Out:
# ['BusinessYear',
#  'StateCode',
#  'RateEffectiveDate',
#  'RateExpirationDate',
#  'PlanId',
#  'RatingAreaId',
#  'Tobacco',
#  'Age',
#  'IndividualRate',
#  'IndividualTobaccoRate',
#  'Couple',
#  'PrimarySubscriberAndOneDependent',
#  'PrimarySubscriberAndTwoDependents',
#  'PrimarySubscriberAndThreeOrMoreDependents',
#  'CoupleAndOneDependent',
#  'CoupleAndTwoDependents',
#  'CoupleAndThreeOrMoreDependents',
#  'RowNumber',
#  'Dental Care, Basic - Child',
#  'Dental Care, Major - Child',
#  'Orthodontia - Child',
#  'Dental, Accidental - Adult',
#  'Dental Care, Basic - Adult',
#  'Dental Care, Major - Adult',
#  'Dental Care, Routine - Adult',
#  'Orthodontia - Adult',
#  'Delivery and All Inpatient Services for Maternity Care',
#  'Durable Medical Equipment',
#  'Emergency Room Services',
#  'Emergency Transportation/Ambulance',
#  'Eyeglasses - Child',
#  'Drugs, Generic',
#  'Home Health Care Services',
#  'Hospice Services',
#  'Imaging (CT/PET Scans, MRIs)',
#  'Inpatient Hospital Services (e.g., Hospital Stay)',
#  'Inpatient Physician and Surgical Services',
#  'Lab Services',
#  'Mental Health',
#  'Drugs, Specialty - Non-Preferred',
#  'Rehabilitation, Outpatient',
#  'Drugs, Preferred Brand',
#  'Prenatal and Postnatal Care',
#  'Preventive Care/Screening/Immunization',
#  'Primary Care',
#  'Vision - Child',
#  'Nursing Facility, Skilled',
#  'Specialist Visit',
#  'Substance Abuse Disorder Inpatient Services',
#  'Substance Abuse Disorder Outpatient Services',
#  'Urgent Care Centers or Facilities',
#  'X-rays and Diagnostic Imaging',
#  'Chiropractic Care',
#  'Infusion Therapy',
#  'Dialysis',
#  'Transplant',
#  'Habilitation',
#  'Chemotherapy',
#  'Radiation',
#  'Physical and Occupational Therapy - Rehabilitative',
#  'Speech Therapy - Rehabilitative',
#  'Reconstructive Surgery',
#  'Diabetes Education',
#  'Prosthetic Devices',
#  'Allergy Testing',
#  'Well Baby Visits and Care',
#  'Temporomandibular Joint Disorder Treatment',
#  'Nutritional Counseling',
#  'Hearing Aids',
#  'Infertility Treatment',
#  'Vision - Adult',
#  'Bariatric Surgery',
#  'Foot Care, Routine',
#  'Nursing, Private-Duty',
#  'Traveling Care (Non-Emergency)',
#  'Family Planning',
#  'Cosmetic Surgery',
#  'Acupuncture',
#  'Weight Loss Programs',
#  'Nursing Home Care',
#  'Diabetes Care Management',
#  'Dental Anesthesia',
#  'Drugs, Prescription - Other',
#  'Drugs, Prescription - Off Label',
#  'PKU (Phenylketonuria)',
#  'Clinical Trials',
#  'Autism Spectrum Disorders',
#  'Congenital Anomaly, including Cleft Lip/Palate',
#  'Bone Marrow Transplant',
#  'Newborn Services Other',
#  'Brain Injury',
#  'Bones/Joints',
#  'Mastectomy',
#  'Osteoporosis',
#  'Pediatric Services Other',
#  'Transplant Donor Coverage',
#  'Nutrition/Formulas',
#  'Breast Implant Removal',
#  'Multiple Sclerosis',
#  'Organ Transplants',
#  'Vision Correction after Surgery or Accident',
#  'Dental Care, Non-Routine - Adult',
#  'Early Intervention Services',
#  'Applied Behavior Analysis Based Therapies',
#  'Well Child Care',
#  'Blood and Blood Services',
#  'Rehabilitation, Inpatient',
#  'Heart Transplant',
#  'Drugs, Generic - Non-Preferred',
#  'Rape and Incest Coverage',
#  'Cardiac and Pulmonary Rehabilitation',
#  'Genetic Testing',
#  'Hyperbaric Oxygen Therapy',
#  'Outpatient Observation',
#  'Cochlear Implants',
#  'Breast Reconstructive Surgery',
#  'Sickle Cell Anemia',
#  'Ostomy Supplies',
#  'Cancer Treatments',
#  'Domestic Violence Treatment',
#  'Infant Formula',
#  'Second Opinion',
#  'Third Opinion',
#  'Hemophilia Treatment',
#  "Wilm's Tumor",
#  'Orthodontia, Cosmetic - Child',
#  'Morbid Obesity Treatment',
#  'HIV/AIDS',
#  'Bone Marrow Testing',
#  'Dental, Accidental - Child',
#  'Newborn Hearing Screening',
#  'Telemedicine',
#  'Second Surgical Opinion',
#  'Attention Deficit Disorder',
#  'Gym Access',
#  'Drugs, Prescription - Tier 2',
#  'Anesthesia',
#  'Colonoscopy',
#  'Eye Refractive Surgery',
#  'Sigmoidoscopy',
#  'Sterilization, Voluntary',
#  'Hearing Exam',
#  'Wigs',
#  'Contraceptive Services',
#  'Sterilization',
#  'Gastric Electrical Stimulation',
#  'Drugs, Preventive',
#  'Retail Health Clinics',
#  'Glaucoma, Soft Lenses or Sclera Shells for',
#  'Fitness',
#  'Naprapathic Services',
#  'Cancer Treatments - Child',
#  'Craniofacial Surgery',
#  'Lymph Node Dissection',
#  'Sleep Studies',
#  'Wellness Rewards',
#  'Low Protein Foods',
#  'Renal Disease, End Stage',
#  'Gastric Disorder Formula',
#  'Leukocyte Antigen Testing',
#  'Orthognathic Surgery',
#  'Pulmonary Rehabilitation Therapy',
#  'Interpreter / Transliterator',
#  'Substance Use Disorders - Intermediate',
#  'Eyeglasses - Adult',
#  'Prosthetics for Diabetics',
#  'Sealants',
#  'Chlamydia Screening',
#  'Oral Surgery - Complex',
#  'Dental X-Rays',
#  'Extractions',
#  'Dentures - Adult',
#  'Occlusal Adjustments',
#  'Pulpotomy, Partial',
#  'Periodontal - Adult',
#  'Lab Services - Quest',
#  'Step Rewards',
#  'Vital Pulpotomy',
#  'Drugs, Generic - Tier 2',
#  'Topical Fluoride',
#  'Biofeedback for Treatment of Medical Diagnosis',
#  'Breast Cancer Pain Medication and Therapy',
#  'Cancer Drug Administration',
#  'Dietician Services',
#  'Electroconvulsive Therapy',
#  'Fibrocystic Breast Condition',
#  'Growth Hormones',
#  'Periadicular - Adult',
#  'Dental Post and Core Build-up',
#  'Prenatal HIV Testing',
#  'Root Canal Therapy and Treatment',
#  'Tissue Conditioning',
#  'Air Ambulance',
#  'Dental Care, Minor - Child',
#  'Smoking and Tobacco Cessation Counseling',
#  'Step Tracking',
#  'Free PCP/Mental Health Visits (Three)',
#  'Fillings',
#  'Medical Massage',
#  'Removal of Fixed Space Maintainers',
#  'Spinal Manipulation',
#  'Contraceptive Devices',
#  'Massage Therapy',
#  'Dental Bridges - Child',
#  'Dental Crowns - Child',
#  'Endodontics - Child',
#  'Habilitation - Autism',
#  'Periodontal - Child',
#  'Dental Cleanings - Child',
#  'Fillings - Child',
#  'Restorative Services',
#  'X-Rays and Exams - Child',
#  'Dental Bridges - Adult',
#  'Dental Crowns - Adult',
#  'Dentures - Child',
#  'Endodontics - Adult',
#  'Habilitation - Acquired Brain Injury',
#  'Dental Cleanings - Adult',
#  'Surgical Extraction - Adult',
#  'Surgical Extraction - Child',
#  'Cosmetic Orthodontia',
#  'Renal Dialysis, End Stage',
#  'Post-cochlear implant aural therapy',
#  'X-Rays and Exams - Adult',
#  'Dental Care, Minor - Adult',
#  'IsNoticeRequiredForPregnancy',
#  'IsReferralRequiredForSpecialist',
#  'ChildOnlyOffering',
#  'WellnessProgramOffered',
#  'DiseaseManagementProgramsOffered',
#  'OutOfCountryCoverage',
#  'NationalNetwork']

# %% [markdown]
# ## Add a unique key to each plan, called `'ben_key'`

# %%
df['ben_key'] = df.groupby(ben_cols_dum).ngroup()

# %%
ben_key_cols_dum = ben_cols_dum

# %%
ben_key_cols_dum.append('ben_key')

# %% [markdown]
# Drop duplicate rows (based on the benefits columns `ben_cols_dum`) to view the vectors that are unique.

# %%
no_dupes = df[ben_key_cols_dum].set_index('ben_key').drop_duplicates()

# %%
no_dupes.head(3)
# Out:
#          Dental Care, Basic - Child  Dental Care, Major - Child  \
# ben_key
# 21                                1                           1
# 174                               1                           1
# 17                                1                           1
#
#          Orthodontia - Child  Dental, Accidental - Adult  \
# ben_key
# 21                         1                           0
# 174                        1                           1
# 17                         1                           0
#
#          Dental Care, Basic - Adult  Dental Care, Major - Adult  \
# ben_key
# 21                                1                           1
# 174                               1                           1
# 17                                0                           0
#
#          Dental Care, Routine - Adult  Orthodontia - Adult  \
# ben_key
# 21                                  1                    0
# 174                                 1                    1
# 17                                  0                    0
#
#          Delivery and All Inpatient Services for Maternity Care  \
# ben_key
# 21                                                       0
# 174                                                      1
# 17                                                       0
#
#          Durable Medical Equipment             ...              \
# ben_key                                        ...
# 21                               0             ...
# 174                              1             ...
# 17                               0             ...
#
#          Endodontics - Adult  Habilitation - Acquired Brain Injury  \
# ben_key
# 21                         0                                     0
# 174                        0                                     0
# 17                         0                                     0
#
#          Dental Cleanings - Adult  Surgical Extraction - Adult  \
# ben_key
# 21                              0                            0
# 174                             0                            0
# 17                              0                            0
#
#          Surgical Extraction - Child  Cosmetic Orthodontia  \
# ben_key
# 21                                 0                     0
# 174                                0                     0
# 17                                 0                     0
#
#          Renal Dialysis, End Stage  Post-cochlear implant aural therapy  \
# ben_key
# 21                               0                                    0
# 174                              0                                    0
# 17                               0                                    0
#
#          X-Rays and Exams - Adult  Dental Care, Minor - Adult
# ben_key
# 21                              0                           0
# 174                             0                           0
# 17                              0                           0
#
# [3 rows x 207 columns]

# %%
no_dupes.shape
# Out:
# (215, 207)

# %% [markdown]
# ## Find cosine similarity using `ben_cols_dum`

# %% [markdown]
# To analyze the resulting dataframe of unique rows, let's look at the cosine similarity between rows:

# %%
cos_mat = cosine_similarity(no_dupes, no_dupes)

# %%
cos_df = pd.DataFrame(cos_mat, columns=no_dupes.index, index=no_dupes.index)

# %%
cos_df.head(3)
# Out:
# ben_key       21        174       17        98        94        88        90   \
# ben_key
# 21       1.000000  0.284747  0.707107  0.679366  0.866025  0.283069  0.277778
# 174      0.284747  1.000000  0.201347  0.257930  0.328798  0.789912  0.806784
# 17       0.707107  0.201347  1.000000  0.480384  0.612372  0.240192  0.235702
#
# ben_key       91        89        101    ...          47        52        48   \
# ben_key                                  ...
# 21       0.272772  0.277778  0.489898    ...     0.165145  0.163663  0.163663
# 174      0.823315  0.806784  0.185996    ...     0.783741  0.792246  0.792246
# 17       0.231455  0.235702  0.346410    ...     0.233550  0.231455  0.231455
#
# ben_key       53        161       93        50        162       45        109
# ben_key
# 21       0.162221  0.294884  0.866025  0.165145  0.292770  0.165145  0.313625
# 174      0.800664  0.895653  0.287698  0.783741  0.889232  0.783741  0.833503
# 17       0.229416  0.208514  0.612372  0.233550  0.207020  0.233550  0.221766
#
# [3 rows x 215 columns]

# %% [markdown]
# The benefit key (`'ben_key'`) of each row can be obtained using the `.name()` function.

# %%
cos_df.iloc[2,:].name
# Out:
# 17

# %% [markdown]
# The below returns the `'ben_key'`s that are most similar to vector created by the user's input:

# %%
my_plan = cos_df.iloc[2,:].sort_values(ascending=False).head(11)[1:]

# %%
print("Ben_key #s most similar to ben_key #", cos_df.iloc[2,:].name, ":", list(my_plan.index))
# Out:
# Ben_key #s most similar to ben_key # 17 : [26, 18, 19, 27, 20, 84, 21, 10, 92, 22]

# %% [markdown]
# And, we can look up that ben_key in our original dataframe.
# However, we want to look up these values in a filtered dataframe.

# %%
df[df['ben_key'] == my_plan.index[0]].head(3)
# Out:
#         BusinessYear StateCode RateEffectiveDate RateExpirationDate  \
# 122464          2016        AZ        2016-01-01         2016-12-31
# 122465          2016        AZ        2016-01-01         2016-12-31
# 122466          2016        AZ        2016-01-01         2016-12-31
#
#                 PlanId   RatingAreaId        Tobacco   Age  IndividualRate  \
# 122464  86830AZ0050001  Rating Area 1  No Preference  0-20            31.0
# 122465  86830AZ0050001  Rating Area 1  No Preference    21          9999.0
# 122466  86830AZ0050001  Rating Area 1  No Preference    22          9999.0
#
#         IndividualTobaccoRate   ...     X-Rays and Exams - Adult  \
# 122464                    NaN   ...                            0
# 122465                    NaN   ...                            0
# 122466                    NaN   ...                            0
#
#         Dental Care, Minor - Adult  IsNoticeRequiredForPregnancy  \
# 122464                           0                           NaN
# 122465                           0                           NaN
# 122466                           0                           NaN
#
#         IsReferralRequiredForSpecialist  ChildOnlyOffering  \
# 122464                              NaN  Allows Child-Only
# 122465                              NaN  Allows Child-Only
# 122466                              NaN  Allows Child-Only
#
#         WellnessProgramOffered  DiseaseManagementProgramsOffered  \
# 122464                     NaN                               NaN
# 122465                     NaN                               NaN
# 122466                     NaN                               NaN
#
#         OutOfCountryCoverage  NationalNetwork  ben_key
# 122464                   Yes              Yes       26
# 122465                   Yes              Yes       26
# 122466                   Yes              Yes       26
#
# [3 rows x 233 columns]

# %% [markdown]
# ## Filter dataframe

# %%
df[(df['Age'] == '40') & (df['StateCode'] == 'AZ' )].head(3)
# Out:
#        BusinessYear StateCode RateEffectiveDate RateExpirationDate  \
# 77846          2016        AZ        2016-01-01         2016-12-31
# 77892          2016        AZ        2016-01-01         2016-12-31
# 77938          2016        AZ        2016-01-01         2016-12-31
#
#                PlanId   RatingAreaId        Tobacco Age  IndividualRate  \
# 77846  12303AZ0010001  Rating Area 1  No Preference  40             0.0
# 77892  12303AZ0010001  Rating Area 2  No Preference  40             0.0
# 77938  12303AZ0010001  Rating Area 3  No Preference  40             0.0
#
#        IndividualTobaccoRate   ...     X-Rays and Exams - Adult  \
# 77846                    NaN   ...                            0
# 77892                    NaN   ...                            0
# 77938                    NaN   ...                            0
#
#        Dental Care, Minor - Adult  IsNoticeRequiredForPregnancy  \
# 77846                           0                           NaN
# 77892                           0                           NaN
# 77938                           0                           NaN
#
#        IsReferralRequiredForSpecialist  ChildOnlyOffering  \
# 77846                              NaN  Allows Child-Only
# 77892                              NaN  Allows Child-Only
# 77938                              NaN  Allows Child-Only
#
#        WellnessProgramOffered  DiseaseManagementProgramsOffered  \
# 77846                     NaN                               NaN
# 77892                     NaN                               NaN
# 77938                     NaN                               NaN
#
#        OutOfCountryCoverage  NationalNetwork  ben_key
# 77846                    No               No       94
# 77892                    No               No       94
# 77938                    No               No       94
#
# [3 rows x 233 columns]

# %% [markdown]
# ## Generate a unique vector

# %%
customplan = pd.DataFrame(data=0, columns=[col for col in ben_key_cols_dum if col != 'ben_key'], index=['customplan'])

# %%
customplan.columns
# Out:
# Index(['Dental Care, Basic - Child', 'Dental Care, Major - Child',
#        'Orthodontia - Child', 'Dental, Accidental - Adult',
#        'Dental Care, Basic - Adult', 'Dental Care, Major - Adult',
#        'Dental Care, Routine - Adult', 'Orthodontia - Adult',
#        'Delivery and All Inpatient Services for Maternity Care',
#        'Durable Medical Equipment',
#        ...
#        'Endodontics - Adult', 'Habilitation - Acquired Brain Injury',
#        'Dental Cleanings - Adult', 'Surgical Extraction - Adult',
#        'Surgical Extraction - Child', 'Cosmetic Orthodontia',
#        'Renal Dialysis, End Stage', 'Post-cochlear implant aural therapy',
#        'X-Rays and Exams - Adult', 'Dental Care, Minor - Adult'],
#       dtype='object', length=207)

# %%
customplan['Dental Care, Basic - Child'] = 1

# %%
customplan.head()
# Out:
#             Dental Care, Basic - Child  Dental Care, Major - Child  \
# customplan                           1                           0
#
#             Orthodontia - Child  Dental, Accidental - Adult  \
# customplan                    0                           0
#
#             Dental Care, Basic - Adult  Dental Care, Major - Adult  \
# customplan                           0                           0
#
#             Dental Care, Routine - Adult  Orthodontia - Adult  \
# customplan                             0                    0
#
#             Delivery and All Inpatient Services for Maternity Care  \
# customplan                                                  0
#
#             Durable Medical Equipment             ...              \
# customplan                          0             ...
#
#             Endodontics - Adult  Habilitation - Acquired Brain Injury  \
# customplan                    0                                     0
#
#             Dental Cleanings - Adult  Surgical Extraction - Adult  \
# customplan                         0                            0
#
#             Surgical Extraction - Child  Cosmetic Orthodontia  \
# customplan                            0                     0
#
#             Renal Dialysis, End Stage  Post-cochlear implant aural therapy  \
# customplan                          0                                    0
#
#             X-Rays and Exams - Adult  Dental Care, Minor - Adult
# customplan                         0                           0
#
# [1 rows x 207 columns]

# %%
no_dupes.shape, customplan.shape
# Out:
# ((215, 207), (1, 207))

# %%
custom_cos_mat = cosine_similarity(customplan, no_dupes)

# %%
custom_cos_df = pd.DataFrame(custom_cos_mat, columns=no_dupes.index, index=customplan.index)

# %%
custom_cos_df
# Out:
# ben_key          21        174      17       98        94        88   \
# customplan  0.408248  0.116248  0.57735  0.27735  0.353553  0.138675
#
# ben_key          90        91        89   101    ...         47        52   \
# customplan  0.136083  0.133631  0.136083  0.2    ...     0.13484  0.133631
#
# ben_key          48        53        161       93       50        162  \
# customplan  0.133631  0.132453  0.120386  0.353553  0.13484  0.119523
#
# ben_key         45        109
# customplan  0.13484  0.128037
#
# [1 rows x 215 columns]

# %%
custom_my_plan = custom_cos_df.iloc[0,:].sort_values(ascending=False).head(11)[1:]

# %%
print("Ben_keys most similar to", custom_cos_df.iloc[0,:].name, ":", list(custom_my_plan.index))
# Out:
# Ben_keys most similar to customplan : [17, 3, 10, 26, 18, 27, 19, 9, 21, 84]

# %%
df[df['ben_key'] == custom_my_plan.index[0]].head(3)
# Out:
#      BusinessYear StateCode RateEffectiveDate RateExpirationDate  \
# 638          2016        AK        2016-01-01         2016-03-31
# 639          2016        AK        2016-04-01         2016-06-30
# 640          2016        AK        2016-07-01         2016-09-30
#
#              PlanId   RatingAreaId        Tobacco            Age  \
# 638  21989AK0110001  Rating Area 1  No Preference  Family Option
# 639  21989AK0110001  Rating Area 1  No Preference  Family Option
# 640  21989AK0110001  Rating Area 1  No Preference  Family Option
#
#      IndividualRate  IndividualTobaccoRate   ...     X-Rays and Exams - Adult  \
# 638             0.0                    NaN   ...                            0
# 639             0.0                    NaN   ...                            0
# 640             0.0                    NaN   ...                            0
#
#      Dental Care, Minor - Adult  IsNoticeRequiredForPregnancy  \
# 638                           0                           NaN
# 639                           0                           NaN
# 640                           0                           NaN
#
#      IsReferralRequiredForSpecialist  ChildOnlyOffering  \
# 638                              NaN  Allows Child-Only
# 639                              NaN  Allows Child-Only
# 640                              NaN  Allows Child-Only
#
#      WellnessProgramOffered  DiseaseManagementProgramsOffered  \
# 638                     NaN                               NaN
# 639                     NaN                               NaN
# 640                     NaN                               NaN
#
#      OutOfCountryCoverage  NationalNetwork  ben_key
# 638                    No              Yes       17
# 639                    No              Yes       17
# 640                    No              Yes       17
#
# [3 rows x 233 columns]
