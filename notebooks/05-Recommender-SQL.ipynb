# %% [markdown]
# # Similarity of plans
#
# In this notebook, I will ask users to select plan benefits that are most important to them and create a vector based on those selections. This vector object is the primary mechanism of comparison for plans. These vectors can just be thought of as geometrical vectors, and so should have an angle between them. This angle is precisely the quantity which the similarity score we will use, cosine similarity, implicitly measures. Two vectors have a higher similarity score when the angle between them is smaller.
#
# I will compare this user-generated vector with the unique plan vectors available in our `no_dupes` dataframe to analyze their similarity. When we talk about whether or not two plans are similar, we're really talking about the similarity of the vectors.
#
# I use numpy to perform efficient numerical matrix operations and some sorting. I use the tkinter library to obtain user input via a GUI.
#
# # Outcome
#
# This recommender system could be useful to a benefits broker as a proprietary tool used to help clients select a health plan that is best suited to their companies.
#
# This recommender system could also be used by an HR manager at a company to self-select plans based on the features selected in the health plan.
#
# The recommender systems alleviates certain difficulties in selecting plans based on features. Most websites allow users to compare plans on price only. However, the features that are included or excluded from low price plans, as compared to high price plans, may be unclear.

# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity

import pickle
from tabulate import tabulate

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2
# set up connection to database (with username/pw if needed)
engine = create_engine('postgres://postgres:postgres@54.190.31.46:5432/')

# %%
# with open ('../pickles/df.pkl', 'rb') as pkl:
#     df = pickle.load(pkl)

# %%
with open ('../pickles/rate_cols.pkl', 'rb') as pkl:
    rate_cols = pickle.load(pkl)
    excl = ['BusinessYear', 'RateEffectiveDate', 'RateExpirationDate', 'RowNumber']
    rate_cols = [col for col in rate_cols if col not in excl]

# %%
# we will use these "excluded" columns in a list comprehension in a later cell
exclude = ['BusinessYear',
'StateCode',
'RateEffectiveDate',
'RateExpirationDate',
'PlanId',
'RatingAreaId',
'Tobacco',
'Age',
'IndividualRate',
'IndividualTobaccoRate',
'Couple',
'PrimarySubscriberAndOneDependent',
'PrimarySubscriberAndTwoDependents',
'PrimarySubscriberAndThreeOrMoreDependents',
'CoupleAndOneDependent',
'CoupleAndTwoDependents',
'CoupleAndThreeOrMoreDependents',
'RowNumber',
'IsNoticeRequiredForPregnancy',
'IsReferralRequiredForSpecialist',
'ChildOnlyOffering',
'WellnessProgramOffered',
'DiseaseManagementProgramsOffered',
'OutOfCountryCoverage',
'NationalNetwork',
'ben_key']

# %% [markdown]
# ## Filter the data
#
# Below, users can filter by a couple of parameters, as follows:
#
# - `'Age'`
# - `'Tobacco User'`
# - `'State'`
#
# Other filters the user can select for include:
#
# - `'IsNoticeRequiredForPregnancy'`: Yes / No / No Preference
# - `'IsReferralRequiredForSpecialist'`: Yes / No / No Preference
# - `'ChildOnlyOffering'`: Allows Child-Only, Allows Adult and Child-Only
# - `'WellnessProgramOffered'`: Yes / No / No Preference
# - `'OutOfCountryCoverage'`: Yes / No
# - `'NationalNetwork'`: Yes / No

# %%
def filter_plans(age, tobacco, state):
    if tobacco == 'yes':
        query = f"""
        SELECT *
        FROM small
        WHERE "StateCode"={state} 
        AND "Age"={age}
        AND "IndividualTobaccoRate" IS NOT NULL
        """
        filtered_df = pd.read_sql(query, con=engine)
    else:
        query = f"""
        SELECT *
        FROM small
        WHERE "StateCode"={state} 
        AND "Age"={age}
        """
        filtered_df = pd.read_sql(query, con=engine)
    return filtered_df

# %% [markdown]
# Below are the additional criteria on which users can filter, with all available choices.

# %%
other_feats = {
'IsNoticeRequiredForPregnancy': [None, 'Yes', 'No'],
'IsReferralRequiredForSpecialist': [None, 'Yes', 'No'],
'ChildOnlyOffering': ['Allows Child-Only', 'Allows Adult and Child-Only'],
'WellnessProgramOffered': [None, 'Yes', 'No'],
'OutOfCountryCoverage': ['Yes', 'No'],
'NationalNetwork': ['No', 'Yes', 'YEs']
}

# %%
def addl_filter(age, tobacco, state, feats=other_feats):
    filtered_df = filter_plans(age, tobacco, state)
    for feat in feats:
        filtered_df = filtered_df[filtered_df[feat].isin(feats[feat])]
    return filtered_df

# %% [markdown]
# Below, users can customize to include only those choices they are interested in, and then run the `addl_filter` function and pass `my_feats` as a parameter.

# %%
my_feats = {
'IsNoticeRequiredForPregnancy': [None, 'Yes', 'No'],
'IsReferralRequiredForSpecialist': [None, 'Yes', 'No'],
'ChildOnlyOffering': ['Allows Child-Only', 'Allows Adult and Child-Only'],
'WellnessProgramOffered': [None, 'Yes', 'No'],
'OutOfCountryCoverage': ['Yes', 'No'],
'NationalNetwork': ['No', 'Yes', 'YEs']
}

# %%
df_filt = addl_filter("'30'", "'no_pref'", "'AZ'", my_feats)
df_filt.head()
# Out:
#       BusinessYear StateCode          PlanId   RatingAreaId  \
# 0             2016        AZ  12303AZ0010001  Rating Area 1
# 1             2016        AZ  12303AZ0010001  Rating Area 2
# 2             2016        AZ  12303AZ0010001  Rating Area 3
# 3             2016        AZ  12303AZ0010001  Rating Area 4
# 4             2016        AZ  12303AZ0010001  Rating Area 5
# 5             2016        AZ  12303AZ0010001  Rating Area 6
# 6             2016        AZ  12303AZ0010001  Rating Area 7
# 7             2016        AZ  12303AZ0020003  Rating Area 1
# 8             2016        AZ  12303AZ0020003  Rating Area 2
# 9             2016        AZ  12303AZ0020003  Rating Area 3
# 10            2016        AZ  12303AZ0020003  Rating Area 4
# 11            2016        AZ  12303AZ0020003  Rating Area 5
# 12            2016        AZ  12303AZ0020003  Rating Area 6
# 13            2016        AZ  12303AZ0020003  Rating Area 7
# 14            2016        AZ  12303AZ0010003  Rating Area 1
# 15            2016        AZ  12303AZ0010003  Rating Area 2
# 16            2016        AZ  12303AZ0010003  Rating Area 3
# 17            2016        AZ  12303AZ0010003  Rating Area 4
# 18            2016        AZ  12303AZ0010003  Rating Area 5
# 19            2016        AZ  12303AZ0010003  Rating Area 6
# 20            2016        AZ  12303AZ0010003  Rating Area 7
# 21            2016        AZ  12303AZ0020004  Rating Area 1
# 22            2016        AZ  12303AZ0020004  Rating Area 2
# 23            2016        AZ  12303AZ0020004  Rating Area 3
# 24            2016        AZ  12303AZ0020004  Rating Area 4
# 25            2016        AZ  12303AZ0020004  Rating Area 5
# 26            2016        AZ  12303AZ0020004  Rating Area 6
# 27            2016        AZ  12303AZ0020004  Rating Area 7
# 28            2016        AZ  12303AZ0010004  Rating Area 1
# 29            2016        AZ  12303AZ0010004  Rating Area 2
# ...            ...       ...             ...            ...
# 1193          2016        AZ  98971AZ0020009  Rating Area 6
# 1194          2016        AZ  98971AZ0020009  Rating Area 7
# 1195          2016        AZ  98971AZ0020012  Rating Area 1
# 1196          2016        AZ  98971AZ0020012  Rating Area 2
# 1197          2016        AZ  98971AZ0020012  Rating Area 3
# 1198          2016        AZ  98971AZ0020012  Rating Area 4
# 1199          2016        AZ  98971AZ0020012  Rating Area 5
# 1200          2016        AZ  98971AZ0020012  Rating Area 6
# 1201          2016        AZ  98971AZ0020012  Rating Area 7
# 1202          2016        AZ  98971AZ0020002  Rating Area 1
# 1203          2016        AZ  98971AZ0020002  Rating Area 2
# 1204          2016        AZ  98971AZ0020002  Rating Area 3
# 1205          2016        AZ  98971AZ0020002  Rating Area 4
# 1206          2016        AZ  98971AZ0020002  Rating Area 5
# 1207          2016        AZ  98971AZ0020002  Rating Area 6
# 1208          2016        AZ  98971AZ0020002  Rating Area 7
# 1209          2016        AZ  98971AZ0020001  Rating Area 1
# 1210          2016        AZ  98971AZ0020001  Rating Area 2
# 1211          2016        AZ  98971AZ0020001  Rating Area 3
# 1212          2016        AZ  98971AZ0020001  Rating Area 4
# 1213          2016        AZ  98971AZ0020001  Rating Area 5
# 1214          2016        AZ  98971AZ0020001  Rating Area 6
# 1215          2016        AZ  98971AZ0020001  Rating Area 7
# 1216          2016        AZ  98971AZ0020003  Rating Area 1
# 1217          2016        AZ  98971AZ0020003  Rating Area 2
# 1218          2016        AZ  98971AZ0020003  Rating Area 3
# 1219          2016        AZ  98971AZ0020003  Rating Area 4
# 1220          2016        AZ  98971AZ0020003  Rating Area 5
# 1221          2016        AZ  98971AZ0020003  Rating Area 6
# 1222          2016        AZ  98971AZ0020003  Rating Area 7
#
#                             Tobacco Age  IndividualRate  \
# 0                     No Preference  30            0.00
# 1                     No Preference  30            0.00
# 2                     No Preference  30            0.00
# 3                     No Preference  30            0.00
# 4                     No Preference  30            0.00
# 5                     No Preference  30            0.00
# 6                     No Preference  30            0.00
# 7                     No Preference  30           24.50
# 8                     No Preference  30           24.50
# 9                     No Preference  30           24.50
# 10                    No Preference  30           24.50
# 11                    No Preference  30           24.50
# 12                    No Preference  30           24.50
# 13                    No Preference  30           24.50
# 14                    No Preference  30           32.12
# 15                    No Preference  30           32.12
# 16                    No Preference  30           32.12
# 17                    No Preference  30           32.12
# 18                    No Preference  30           32.12
# 19                    No Preference  30           32.12
# 20                    No Preference  30           32.12
# 21                    No Preference  30           18.23
# 22                    No Preference  30           18.23
# 23                    No Preference  30           18.23
# 24                    No Preference  30           18.23
# 25                    No Preference  30           18.23
# 26                    No Preference  30           18.23
# 27                    No Preference  30           18.23
# 28                    No Preference  30           23.91
# 29                    No Preference  30           23.91
# ...                             ...  ..             ...
# 1193  Tobacco User/Non-Tobacco User  30          194.40
# 1194  Tobacco User/Non-Tobacco User  30          276.11
# 1195  Tobacco User/Non-Tobacco User  30          391.20
# 1196  Tobacco User/Non-Tobacco User  30          370.96
# 1197  Tobacco User/Non-Tobacco User  30          247.99
# 1198  Tobacco User/Non-Tobacco User  30          237.74
# 1199  Tobacco User/Non-Tobacco User  30          287.70
# 1200  Tobacco User/Non-Tobacco User  30          199.31
# 1201  Tobacco User/Non-Tobacco User  30          283.09
# 1202  Tobacco User/Non-Tobacco User  30          315.20
# 1203  Tobacco User/Non-Tobacco User  30          298.89
# 1204  Tobacco User/Non-Tobacco User  30          199.81
# 1205  Tobacco User/Non-Tobacco User  30          191.55
# 1206  Tobacco User/Non-Tobacco User  30          231.81
# 1207  Tobacco User/Non-Tobacco User  30          160.59
# 1208  Tobacco User/Non-Tobacco User  30          228.09
# 1209  Tobacco User/Non-Tobacco User  30          331.40
# 1210  Tobacco User/Non-Tobacco User  30          314.26
# 1211  Tobacco User/Non-Tobacco User  30          210.08
# 1212  Tobacco User/Non-Tobacco User  30          201.40
# 1213  Tobacco User/Non-Tobacco User  30          243.72
# 1214  Tobacco User/Non-Tobacco User  30          168.85
# 1215  Tobacco User/Non-Tobacco User  30          239.82
# 1216  Tobacco User/Non-Tobacco User  30          292.43
# 1217  Tobacco User/Non-Tobacco User  30          277.31
# 1218  Tobacco User/Non-Tobacco User  30          185.38
# 1219  Tobacco User/Non-Tobacco User  30          177.72
# 1220  Tobacco User/Non-Tobacco User  30          215.07
# 1221  Tobacco User/Non-Tobacco User  30          148.99
# 1222  Tobacco User/Non-Tobacco User  30          211.62
#
#       IndividualTobaccoRate Couple PrimarySubscriberAndOneDependent   ...    \
# 0                       NaN   None                             None   ...
# 1                       NaN   None                             None   ...
# 2                       NaN   None                             None   ...
# 3                       NaN   None                             None   ...
# 4                       NaN   None                             None   ...
# 5                       NaN   None                             None   ...
# 6                       NaN   None                             None   ...
# 7                       NaN   None                             None   ...
# 8                       NaN   None                             None   ...
# 9                       NaN   None                             None   ...
# 10                      NaN   None                             None   ...
# 11                      NaN   None                             None   ...
# 12                      NaN   None                             None   ...
# 13                      NaN   None                             None   ...
# 14                      NaN   None                             None   ...
# 15                      NaN   None                             None   ...
# 16                      NaN   None                             None   ...
# 17                      NaN   None                             None   ...
# 18                      NaN   None                             None   ...
# 19                      NaN   None                             None   ...
# 20                      NaN   None                             None   ...
# 21                      NaN   None                             None   ...
# 22                      NaN   None                             None   ...
# 23                      NaN   None                             None   ...
# 24                      NaN   None                             None   ...
# 25                      NaN   None                             None   ...
# 26                      NaN   None                             None   ...
# 27                      NaN   None                             None   ...
# 28                      NaN   None                             None   ...
# 29                      NaN   None                             None   ...
# ...                     ...    ...                              ...   ...
# 1193                 204.12   None                             None   ...
# 1194                 289.91   None                             None   ...
# 1195                 410.76   None                             None   ...
# 1196                 389.51   None                             None   ...
# 1197                 260.39   None                             None   ...
# 1198                 249.63   None                             None   ...
# 1199                 302.08   None                             None   ...
# 1200                 209.28   None                             None   ...
# 1201                 297.24   None                             None   ...
# 1202                 330.96   None                             None   ...
# 1203                 313.83   None                             None   ...
# 1204                 209.80   None                             None   ...
# 1205                 201.13   None                             None   ...
# 1206                 243.40   None                             None   ...
# 1207                 168.62   None                             None   ...
# 1208                 239.49   None                             None   ...
# 1209                 347.97   None                             None   ...
# 1210                 329.97   None                             None   ...
# 1211                 220.59   None                             None   ...
# 1212                 211.47   None                             None   ...
# 1213                 255.91   None                             None   ...
# 1214                 177.29   None                             None   ...
# 1215                 251.81   None                             None   ...
# 1216                 307.06   None                             None   ...
# 1217                 291.17   None                             None   ...
# 1218                 194.65   None                             None   ...
# 1219                 186.61   None                             None   ...
# 1220                 225.82   None                             None   ...
# 1221                 156.44   None                             None   ...
# 1222                 222.20   None                             None   ...
#
#      CoupleAndThreeOrMoreDependents RowNumber IsNoticeRequiredForPregnancy  \
# 0                              None        24                         None
# 1                              None       162                         None
# 2                              None       300                         None
# 3                              None       438                         None
# 4                              None       576                         None
# 5                              None       714                         None
# 6                              None       852                         None
# 7                              None        24                         None
# 8                              None       116                         None
# 9                              None       208                         None
# 10                             None       300                         None
# 11                             None       392                         None
# 12                             None       484                         None
# 13                             None       576                         None
# 14                             None        70                         None
# 15                             None       208                         None
# 16                             None       346                         None
# 17                             None       484                         None
# 18                             None       622                         None
# 19                             None       760                         None
# 20                             None       898                         None
# 21                             None        70                         None
# 22                             None       162                         None
# 23                             None       254                         None
# 24                             None       346                         None
# 25                             None       438                         None
# 26                             None       530                         None
# 27                             None       622                         None
# 28                             None       116                         None
# 29                             None       254                         None
# ...                             ...       ...                          ...
# 1193                           None      2508                           No
# 1194                           None      2554                           No
# 1195                           None      2600                           No
# 1196                           None      2646                           No
# 1197                           None      2692                           No
# 1198                           None      2738                           No
# 1199                           None      2784                           No
# 1200                           None      2830                           No
# 1201                           None      2876                           No
# 1202                           None      2922                           No
# 1203                           None      2968                           No
# 1204                           None      3014                           No
# 1205                           None      3060                           No
# 1206                           None      3106                           No
# 1207                           None      3152                           No
# 1208                           None      3198                           No
# 1209                           None      3244                           No
# 1210                           None      3290                           No
# 1211                           None      3336                           No
# 1212                           None      3382                           No
# 1213                           None      3428                           No
# 1214                           None      3474                           No
# 1215                           None      3520                           No
# 1216                           None      3566                           No
# 1217                           None      3612                           No
# 1218                           None      3658                           No
# 1219                           None      3704                           No
# 1220                           None      3750                           No
# 1221                           None      3796                           No
# 1222                           None      3842                           No
#
#      IsReferralRequiredForSpecialist            ChildOnlyOffering  \
# 0                               None            Allows Child-Only
# 1                               None            Allows Child-Only
# 2                               None            Allows Child-Only
# 3                               None            Allows Child-Only
# 4                               None            Allows Child-Only
# 5                               None            Allows Child-Only
# 6                               None            Allows Child-Only
# 7                               None  Allows Adult and Child-Only
# 8                               None  Allows Adult and Child-Only
# 9                               None  Allows Adult and Child-Only
# 10                              None  Allows Adult and Child-Only
# 11                              None  Allows Adult and Child-Only
# 12                              None  Allows Adult and Child-Only
# 13                              None  Allows Adult and Child-Only
# 14                              None  Allows Adult and Child-Only
# 15                              None  Allows Adult and Child-Only
# 16                              None  Allows Adult and Child-Only
# 17                              None  Allows Adult and Child-Only
# 18                              None  Allows Adult and Child-Only
# 19                              None  Allows Adult and Child-Only
# 20                              None  Allows Adult and Child-Only
# 21                              None  Allows Adult and Child-Only
# 22                              None  Allows Adult and Child-Only
# 23                              None  Allows Adult and Child-Only
# 24                              None  Allows Adult and Child-Only
# 25                              None  Allows Adult and Child-Only
# 26                              None  Allows Adult and Child-Only
# 27                              None  Allows Adult and Child-Only
# 28                              None  Allows Adult and Child-Only
# 29                              None  Allows Adult and Child-Only
# ...                              ...                          ...
# 1193                             Yes  Allows Adult and Child-Only
# 1194                             Yes  Allows Adult and Child-Only
# 1195                             Yes  Allows Adult and Child-Only
# 1196                             Yes  Allows Adult and Child-Only
# 1197                             Yes  Allows Adult and Child-Only
# 1198                             Yes  Allows Adult and Child-Only
# 1199                             Yes  Allows Adult and Child-Only
# 1200                             Yes  Allows Adult and Child-Only
# 1201                             Yes  Allows Adult and Child-Only
# 1202                             Yes  Allows Adult and Child-Only
# 1203                             Yes  Allows Adult and Child-Only
# 1204                             Yes  Allows Adult and Child-Only
# 1205                             Yes  Allows Adult and Child-Only
# 1206                             Yes  Allows Adult and Child-Only
# 1207                             Yes  Allows Adult and Child-Only
# 1208                             Yes  Allows Adult and Child-Only
# 1209                             Yes  Allows Adult and Child-Only
# 1210                             Yes  Allows Adult and Child-Only
# 1211                             Yes  Allows Adult and Child-Only
# 1212                             Yes  Allows Adult and Child-Only
# 1213                             Yes  Allows Adult and Child-Only
# 1214                             Yes  Allows Adult and Child-Only
# 1215                             Yes  Allows Adult and Child-Only
# 1216                             Yes  Allows Adult and Child-Only
# 1217                             Yes  Allows Adult and Child-Only
# 1218                             Yes  Allows Adult and Child-Only
# 1219                             Yes  Allows Adult and Child-Only
# 1220                             Yes  Allows Adult and Child-Only
# 1221                             Yes  Allows Adult and Child-Only
# 1222                             Yes  Allows Adult and Child-Only
#
#       WellnessProgramOffered    DiseaseManagementProgramsOffered  \
# 0                       None                                None
# 1                       None                                None
# 2                       None                                None
# 3                       None                                None
# 4                       None                                None
# 5                       None                                None
# 6                       None                                None
# 7                       None                                None
# 8                       None                                None
# 9                       None                                None
# 10                      None                                None
# 11                      None                                None
# 12                      None                                None
# 13                      None                                None
# 14                      None                                None
# 15                      None                                None
# 16                      None                                None
# 17                      None                                None
# 18                      None                                None
# 19                      None                                None
# 20                      None                                None
# 21                      None                                None
# 22                      None                                None
# 23                      None                                None
# 24                      None                                None
# 25                      None                                None
# 26                      None                                None
# 27                      None                                None
# 28                      None                                None
# 29                      None                                None
# ...                      ...                                 ...
# 1193                      No  Heart Disease, Diabetes, Pregnancy
# 1194                      No  Heart Disease, Diabetes, Pregnancy
# 1195                      No  Heart Disease, Diabetes, Pregnancy
# 1196                      No  Heart Disease, Diabetes, Pregnancy
# 1197                      No  Heart Disease, Diabetes, Pregnancy
# 1198                      No  Heart Disease, Diabetes, Pregnancy
# 1199                      No  Heart Disease, Diabetes, Pregnancy
# 1200                      No  Heart Disease, Diabetes, Pregnancy
# 1201                      No  Heart Disease, Diabetes, Pregnancy
# 1202                      No  Heart Disease, Diabetes, Pregnancy
# 1203                      No  Heart Disease, Diabetes, Pregnancy
# 1204                      No  Heart Disease, Diabetes, Pregnancy
# 1205                      No  Heart Disease, Diabetes, Pregnancy
# 1206                      No  Heart Disease, Diabetes, Pregnancy
# 1207                      No  Heart Disease, Diabetes, Pregnancy
# 1208                      No  Heart Disease, Diabetes, Pregnancy
# 1209                      No  Heart Disease, Diabetes, Pregnancy
# 1210                      No  Heart Disease, Diabetes, Pregnancy
# 1211                      No  Heart Disease, Diabetes, Pregnancy
# 1212                      No  Heart Disease, Diabetes, Pregnancy
# 1213                      No  Heart Disease, Diabetes, Pregnancy
# 1214                      No  Heart Disease, Diabetes, Pregnancy
# 1215                      No  Heart Disease, Diabetes, Pregnancy
# 1216                      No  Heart Disease, Diabetes, Pregnancy
# 1217                      No  Heart Disease, Diabetes, Pregnancy
# 1218                      No  Heart Disease, Diabetes, Pregnancy
# 1219                      No  Heart Disease, Diabetes, Pregnancy
# 1220                      No  Heart Disease, Diabetes, Pregnancy
# 1221                      No  Heart Disease, Diabetes, Pregnancy
# 1222                      No  Heart Disease, Diabetes, Pregnancy
#
#      OutOfCountryCoverage NationalNetwork ben_key
# 0                      No              No      94
# 1                      No              No      94
# 2                      No              No      94
# 3                      No              No      94
# 4                      No              No      94
# 5                      No              No      94
# 6                      No              No      94
# 7                      No              No      94
# 8                      No              No      94
# 9                      No              No      94
# 10                     No              No      94
# 11                     No              No      94
# 12                     No              No      94
# 13                     No              No      94
# 14                     No              No      94
# 15                     No              No      94
# 16                     No              No      94
# 17                     No              No      94
# 18                     No              No      94
# 19                     No              No      94
# 20                     No              No      94
# 21                     No              No      94
# 22                     No              No      94
# 23                     No              No      94
# 24                     No              No      94
# 25                     No              No      94
# 26                     No              No      94
# 27                     No              No      94
# 28                     No              No      94
# 29                     No              No      94
# ...                   ...             ...     ...
# 1193                  Yes              No     157
# 1194                  Yes              No     157
# 1195                  Yes              No     157
# 1196                  Yes              No     157
# 1197                  Yes              No     157
# 1198                  Yes              No     157
# 1199                  Yes              No     157
# 1200                  Yes              No     157
# 1201                  Yes              No     157
# 1202                  Yes              No     157
# 1203                  Yes              No     157
# 1204                  Yes              No     157
# 1205                  Yes              No     157
# 1206                  Yes              No     157
# 1207                  Yes              No     157
# 1208                  Yes              No     157
# 1209                  Yes              No     157
# 1210                  Yes              No     157
# 1211                  Yes              No     157
# 1212                  Yes              No     157
# 1213                  Yes              No     157
# 1214                  Yes              No     157
# 1215                  Yes              No     157
# 1216                  Yes              No     157
# 1217                  Yes              No     157
# 1218                  Yes              No     157
# 1219                  Yes              No     157
# 1220                  Yes              No     157
# 1221                  Yes              No     157
# 1222                  Yes              No     157
#
# [1223 rows x 24 columns]

# %% [markdown]
# ## Filtering by unique plan vectors: `no_dupes`
#
# In a previous notebook, I created a matrix of vectors (called `no_dupes`) in which each vector represented a unique combination of available benefits. No two vectors are the same (however, a particular vector can represent many different types of plans).
#
# Below, I will condense the `no_dupes` matrix to only those plans available based on the filtering performed above.
#
# As you will see, we start off with 215 rows in `no_dupes` (representing 215 unique plan vectors), but after filtering, we are left with far fewer unique plans (the specific amount that remain depends on the filtering criteria from above).

# %%
with open ('../pickles/no_dupes.pkl', 'rb') as pkl:
    no_dupes = pickle.load(pkl)

# %%
no_dupes.shape
# Out:
# (215, 207)

# %%
unique_keys = list(df_filt['ben_key'].unique())

# %%
unique_keys
# Out:
# [94, 17, 21, 214, 24, 77, 71, 68, 19, 8, 86, 101, 6, 156, 26, 76, 78, 7, 157]

# %%
no_dupes = no_dupes[no_dupes.index.isin(unique_keys)]

# %%
no_dupes.shape
# Out:
# (19, 207)

# %% [markdown]
# Below, I am storing the column names and indexes of the filtered dataframe `df_filt` and converting it into a NumPy array for efficient computation. I will use the dictionaries later as a lookup into the NumPy array.

# %%
col_dict = dict(zip(no_dupes.columns, range(len(no_dupes.columns))))

# %%
ind_dict = dict(zip(range(len(no_dupes)), no_dupes.index))

# %%
no_dupes_mat = np.asarray(no_dupes)

# %% [markdown]
# Below, I'm creating a list of benefits that are available for selection based on the `df_filt` from above. This list will be passed into the `tkinter` GUI which will allow users to select from benefits that are actually, verifiably available from the plans they filtered for.

# %%
ben_cols_dum = [col for col in no_dupes if no_dupes[col].sum() != 0]

# %% [markdown]
# ## Generate a unique plan
#
# Using tkinter, Python's inbuilt GUI, I ask users to select the features they would like in their plan, and create a vector based on those selected features. Any benefits that are not selected are treated homogeneously and equal to all other un-selected features, so no information is "lost".

# %%
from tkinter import *
import tkinter as tk

# ----- Section: functions -----

sel_feats = []

def on_keyrelease(event):

    # get text from entry
    value = event.widget.get()
    value = value.strip().lower()

    # get data from test_list
    if value == '':
        data = test_list
    else:
        data = []
        for item in test_list:
            if value in item.lower():
                data.append(item)                

    # update data in listbox
    listbox_update(data)


def listbox_update(data):
    # delete previous data
    l1.delete(0, 'end')

    # sorting data 
    data = sorted(data, key=str.lower)

    # put new data
    for item in data:
        l1.insert('end', item)

def onselect(event):
    selection = l1.curselection()
    for i in selection:
        entry = l1.get(i)
        l2.insert(END, entry)
        print(l1.get(i))
        
def submit(event):
    content = l2.get(0, tk.END)
    for i in content:
        sel_feats.append(i)
    print(sel_feats)

# ----- Section: code -----

test_list = ben_cols_dum

root = Tk()

label = Label(root, text="Type below!")
label.pack(side=TOP)

entry = Entry(root,
             width=40)
entry.pack(side=TOP)
entry.bind('<KeyRelease>', on_keyrelease)

l1 = Listbox(root, 
             selectmode=MULTIPLE, 
             width=40, 
             height=10)
l1.pack(padx=20, pady=20)
listbox_update(test_list)

btn = Button(root, text="Add")
btn.pack()
btn.bind('<Button-1>', onselect)

l2 = Listbox(root, width=40, height=10)
l2.pack(padx=20, pady=20)

btn = Button(root, text="Submit")
btn.pack()
btn.bind('<Button-1>', submit)

root.mainloop()
# Out:
# Autism Spectrum Disorders
# Chemotherapy
# Cosmetic Surgery
# Delivery and All Inpatient Services for Maternity Care
# ['Autism Spectrum Disorders', 'Chemotherapy', 'Cosmetic Surgery', 'Delivery and All Inpatient Services for Maternity Care']

# %%
sel_feats = list(set(sel_feats))

# %%
ben_vec = np.zeros(no_dupes_mat.shape[1])

# %% [markdown]
# Below, I fill in "1s" in my NumPy matrix corresponding to the features selected by the user.

# %%
sel_feats
# Out:
# ['Chemotherapy',
#  'Cosmetic Surgery',
#  'Delivery and All Inpatient Services for Maternity Care',
#  'Autism Spectrum Disorders']

# %%
for benefit in sel_feats:
    ben_vec[col_dict[benefit]] = 1

# %%
ben_vec = np.reshape(ben_vec, (1, -1))

# %%
ben_vec.shape
# Out:
# (1, 207)

# %% [markdown]
# ## Find cosine similarity between `ben_vec` and `no_dupes`

# %%
cos_mat = cosine_similarity(ben_vec, no_dupes_mat)

# %%
i = 0
top_matches = []
for item in cos_mat[0]:
    if item == 0:
        pass
    else:
        top_matches.append([item, ind_dict[i]])
    i += 1
top_matches.sort(reverse=True)

# %% [markdown]
# Below are the plans that best match the user's selected criteria.

# %%
print("Ben_keys most similar to ben_vec:", [b for a, b in top_matches])
# Out:
# Ben_keys most similar to ben_vec: [214, 7, 8, 86, 157, 156, 6, 68, 76, 71, 78, 77]

# %% [markdown]
# ## View plan details
#
# Below, the user can run a couple of functions to view additional details about his select plan and plan variants.

# %%
print("\n", "Using the list below, please find the Index # of the plan variant you would like to view.")
print(tabulate(
    [[top_matches[i][1], top_matches[i][0], i] for i in range(len(top_matches))], 
    ["Plan Variant", "Similarity", "Index #"], 
    tablefmt="grid"
))
# Out:
#  Using the list below, please find the Index # of the plan variant you would like to view.
# +----------------+--------------+-----------+
# |   Plan Variant |   Similarity |   Index # |
# +================+==============+===========+
# |            214 |     0.235702 |         0 |
# +----------------+--------------+-----------+
# |              7 |     0.200446 |         1 |
# +----------------+--------------+-----------+
# |              8 |     0.19696  |         2 |
# +----------------+--------------+-----------+
# |             86 |     0.1905   |         3 |
# +----------------+--------------+-----------+
# |            157 |     0.181902 |         4 |
# +----------------+--------------+-----------+
# |            156 |     0.181902 |         5 |
# +----------------+--------------+-----------+
# |              6 |     0.138675 |         6 |
# +----------------+--------------+-----------+
# |             68 |     0.13484  |         7 |
# +----------------+--------------+-----------+
# |             76 |     0.131306 |         8 |
# +----------------+--------------+-----------+
# |             71 |     0.131306 |         9 |
# +----------------+--------------+-----------+
# |             78 |     0.130189 |        10 |
# +----------------+--------------+-----------+
# |             77 |     0.130189 |        11 |
# +----------------+--------------+-----------+

# %% [markdown]
# Below, please enter your selected Index # in the `covered_feats` function, which will allow you to see the features that are covered in the plan variant:

# %%
def covered_feats(index):
    # Get covered features in dataframe
    feat_coverage = no_dupes[no_dupes.index == top_matches[index][1]][sel_feats].head(10)

    # Plot the features
    x = list(feat_coverage.columns)
    coverage = [1 if feat_coverage[i].sum() > 0 else 0.01 for i in list(feat_coverage.columns)]
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'g']

    x_pos = [i for i, _ in enumerate(x)]

    plt.barh(x_pos, coverage, color='green')
    plt.ylabel("Benefit Name")
    plt.title("Feature availability in selected plan variant")

    plt.yticks(x_pos, x)
    plt.xticks(np.arange(2), ('Not Available', 'Available'))

    plt.show()
    return feat_coverage
feat_coverage = covered_feats(1)

# %% [markdown]
# Below, please enter the index number in the `matching_plans` function corresponding to the plan variant you would like to view. This function will then show you all the available plans in that plan variant.

# %%
def matching_plans(index):
    matches = df_filt[df_filt['ben_key'] == top_matches[index][1]][rate_cols].dropna(axis=1)
    print("\n", "There are", matches.shape[0], """plans available for selection. 
    Showing top 5, sorted by area, then price:""")
    return matches
matches = matching_plans(0).sort_values(['RatingAreaId', 'IndividualRate'])
matches.head()
# Out:
#  There are 72 plans available for selection.
#     Showing all, sorted by area, then price:
#      StateCode          PlanId   RatingAreaId        Tobacco Age  \
# 1053        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1054        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1055        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1056        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1023        AZ  91450AZ0160005  Rating Area 1  No Preference  30
#
#       IndividualRate
# 1053          338.24
# 1054          343.42
# 1055          348.67
# 1056          354.00
# 1023          389.48

# %% [markdown]
# The below shows the user the price by `'RatingAreaId'` - with some areas in the state more expensive than others.

# %%
matches.groupby('RatingAreaId').mean().dropna().sort_values('IndividualRate')
# Out:
#                IndividualRate
# RatingAreaId
# Rating Area 6      258.250000
# Rating Area 4      301.553125
# Rating Area 7      320.416250
# Rating Area 5      325.547500
# Rating Area 1      372.296250
# Rating Area 2      372.296250
# Rating Area 3      372.296250

# %% [markdown]
# The below is a filter for Rating Areas.

# %%
matches[matches['RatingAreaId'] == 'Rating Area 1']
# Out:
#      StateCode          PlanId   RatingAreaId        Tobacco Age  \
# 1053        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1054        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1055        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1056        AZ  91450AZ0160019  Rating Area 1  No Preference  30
# 1023        AZ  91450AZ0160005  Rating Area 1  No Preference  30
# 1024        AZ  91450AZ0160005  Rating Area 1  No Preference  30
# 1025        AZ  91450AZ0160005  Rating Area 1  No Preference  30
# 1026        AZ  91450AZ0160005  Rating Area 1  No Preference  30
#
#       IndividualRate
# 1053          338.24
# 1054          343.42
# 1055          348.67
# 1056          354.00
# 1023          389.48
# 1024          395.44
# 1025          401.49
# 1026          407.63

# %% [markdown]
# ## Viewing plan attributes
#
# Now, we we load in data from `attributes.pkl` and save it as `attributes`. This file contains plan variant-level data on maximum out of pocket payments, deductibles, health savings account (HSA) eligibility, formulary ID, and other plan attributes.

# %%
with open ('../pickles/attributes.pkl', 'rb') as pkl:
    attributes = pickle.load(pkl)

# %%
attr_exclude = [
    'AVCalculatorOutputNumber',
    'BenefitPackageId',
    'BusinessYear',
    'CompositeRatingOffered',
    'FormularyId',
    'HIOSProductId',
    'HPID',
    'ImportDate',
    'IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee',
    'IssuerId',
    'IssuerId2',
    'NetworkId',
    'SourceName',
    'QHPNonQHPTypeId',
    'PlanEffictiveDate',
    'PlanExpirationDate',
    'RowNumber',
    'ServiceAreaId',
    'TIN',
    'VersionNum',
    'StateCode2'
]
attribute_cols = [col for col in list(attributes.columns) if col not in attr_exclude]

# %%
other_feats_key = list(other_feats.keys())

# %%
other_feats_key.append('PlanId')

# %%
# View certains columns from the Attributes file based on the plan we want to view
def view_details(plan, view_cols=other_feats_key):
    details = attributes[attributes['PlanId'] == plan][view_cols].T
    return details

# %% [markdown]
# Now that we have the columns of interest from `attributes`, we can run a cell to view all attributes of interest for each plan in our match.

# %%
# Seed an initial plan in a column to compare against
compare = view_details(plan=matches['PlanId'].iloc[0], view_cols=attribute_cols)

# Merge additional plans from the "matches" df to the first plan
for plan in matches['PlanId'][1:]:
    interim = pd.merge(compare, 
             view_details(plan, attribute_cols),
             left_index=True,
             right_index=True)
    compare = interim

# View the sequence of compared plans
compare = compare.T.set_index('PlanId').T
compare.dropna(how='all')
# Out:
# PlanId                                                                                 91450AZ0160019  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                    Standard Silver Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $6000 per group
# ...                                                                                               ...
# MetalLevel                                                                                     Silver
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                               HMO Silver 3000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,400
# SBCHavingDiabetesDeductible                                                                   $3,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                       $900
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $3,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160019  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                    Standard Silver Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $6000 per group
# ...                                                                                               ...
# MetalLevel                                                                                     Silver
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                               HMO Silver 3000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,400
# SBCHavingDiabetesDeductible                                                                   $3,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                       $900
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $3,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160019  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                    Standard Silver Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $6000 per group
# ...                                                                                               ...
# MetalLevel                                                                                     Silver
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                               HMO Silver 3000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,400
# SBCHavingDiabetesDeductible                                                                   $3,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                       $900
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $3,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160019  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                    Standard Silver Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $6000 per group
# ...                                                                                               ...
# MetalLevel                                                                                     Silver
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                               HMO Silver 3000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,400
# SBCHavingDiabetesDeductible                                                                   $3,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                       $900
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $3,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                    Existing
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $2000 per group
# ...                                                                                               ...
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                    Existing
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $2000 per group
# ...                                                                                               ...
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                    Existing
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $2000 per group
# ...                                                                                               ...
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# ...
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                    Existing
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $2000 per group
# ...                                                                                               ...
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# PlanId                                                                                 91450AZ0160005
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      1
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# DEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# DEHBDedCombInnOonIndividual                                                            Not Applicable
# DEHBDedInnTier1Coinsurance                                                                        20%
# DEHBDedInnTier1FamilyPerGroup                                                per group not applicable
# DEHBDedInnTier1FamilyPerPerson                                                        $500 per person
# DEHBDedInnTier1Individual                                                                       $500
# DEHBDedOutOfNetFamilyPerGroup                                                per group not applicable
# DEHBDedOutOfNetFamilyPerPerson                                              per person not applicable
# DEHBDedOutOfNetIndividual                                                              Not Applicable
# DentalOnlyPlan                                                                                     No
# DiseaseManagementProgramsOffered                    Asthma, Heart Disease, Depression, Diabetes, P...
# EHBPercentTotalPremium                                                                          0.996
# FirstTierUtilization                                                                             100%
# FormularyURL                                        https://www.healthnet.com/static/general/unpro...
# HSAOrHRAEmployerContribution                                                                       No
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                    Existing
# IsNoticeRequiredForPregnancy                                                                      Yes
# IsReferralRequiredForSpecialist                                                                    No
# MEHBDedCombInnOonFamilyPerGroup                                              per group not applicable
# MEHBDedCombInnOonFamilyPerPerson                                            per person not applicable
# MEHBDedCombInnOonIndividual                                                            Not Applicable
# MEHBDedInnTier1Coinsurance                                                                        20%
# MEHBDedInnTier1FamilyPerGroup                                                         $2000 per group
# ...                                                                                               ...
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                               No
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                                         Emergent services covered
# PlanBrochure                                        https://www.healthnet.com/static/shopping/unpr...
# PlanMarketingName                                                 HMO Gold 1000 with pediatric dental
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                    $1,200
# SBCHavingDiabetesDeductible                                                                   $1,000
# SBCHavingDiabetesLimit                                                                           $80
# SBCHavingaBabyCoinsurance                                                                     $1,100
# SBCHavingaBabyCopayment                                                                          $20
# SBCHavingaBabyDeductible                                                                      $1,000
# SBCHavingaBabyLimit                                                                             $200
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                             per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP                                           per person not applicable
# TEHBCombInnOonIndividualMOOP                                                           Not Applicable
# TEHBInnTier1FamilyPerGroupMOOP                                                        $8000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4000 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,000
# TEHBOutOfNetFamilyPerGroupMOOP                                               per group not applicable
# TEHBOutOfNetFamilyPerPersonMOOP                                             per person not applicable
# TEHBOutOfNetIndividualMOOP                                                             Not Applicable
# URLForSummaryofBenefitsCoverage                     https://www.healthnet.com/static/shopping/unpr...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                            Yes
#
# [68 rows x 72 columns]

# %% [markdown]
# ## Viewing deductibles (and coinsurance?)
#
# Using the below function, users can view the deductibles information for their recommended plans.
#
# Coinsurance information is not available to view in the function, as coinsurance can vary within plans, because it is specific to each benefit. For example, in the image below, we can clearly see different coinsurance percentages for different benefit types:
#
# ![](../assets/coins.png)
#
# So, below, users can see their deductible information, but if a user needs to review coinsurance information, they will have to review documentation from CMS.

# %%
def ehb(ehb):
    return compare[compare.index.isin(
        [f'{ehb}CombInnOonFamilyPerGroupMOOP',
         f'{ehb}CombInnOonFamilyPerPersonMOOP',
         f'{ehb}CombInnOonIndividualMOOP',
         f'{ehb}DedCombInnOonFamilyPerGroup',
         f'{ehb}DedCombInnOonFamilyPerPerson',
         f'{ehb}DedCombInnOonIndividual',
         f'{ehb}DedInnTier1Coinsurance',
         f'{ehb}DedInnTier1FamilyPerGroup',
         f'{ehb}DedInnTier1FamilyPerPerson',
         f'{ehb}DedInnTier1Individual',
         f'{ehb}DedOutOfNetFamilyPerGroup',
         f'{ehb}DedOutOfNetFamilyPerPerson',
         f'{ehb}DedOutOfNetIndividual',
         f'{ehb}InnTier1FamilyPerGroupMOOP',
         f'{ehb}InnTier1FamilyPerPersonMOOP',
         f'{ehb}InnTier1IndividualMOOP',
         f'{ehb}OutOfNetFamilyPerGroupMOOP',
         f'{ehb}OutOfNetFamilyPerPersonMOOP',
         f'{ehb}OutOfNetIndividualMOOP']
    )]

# %%
ehb('MEHB').head()
# Out:
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                       ...              \
# MEHBCombInnOonFamilyPerGroupMOOP             ...
# MEHBCombInnOonFamilyPerPersonMOOP            ...
# MEHBCombInnOonIndividualMOOP                 ...
# MEHBDedCombInnOonFamilyPerGroup              ...
# MEHBDedCombInnOonFamilyPerPerson             ...
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005
# MEHBCombInnOonFamilyPerGroupMOOP                         NaN
# MEHBCombInnOonFamilyPerPersonMOOP                        NaN
# MEHBCombInnOonIndividualMOOP                             NaN
# MEHBDedCombInnOonFamilyPerGroup     per group not applicable
# MEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# [5 rows x 72 columns]

# %%
ehb('DEHB').head()
# Out:
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                       ...              \
# DEHBCombInnOonFamilyPerGroupMOOP             ...
# DEHBCombInnOonFamilyPerPersonMOOP            ...
# DEHBCombInnOonIndividualMOOP                 ...
# DEHBDedCombInnOonFamilyPerGroup              ...
# DEHBDedCombInnOonFamilyPerPerson             ...
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160019  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005  \
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# PlanId                                        91450AZ0160005
# DEHBCombInnOonFamilyPerGroupMOOP                         NaN
# DEHBCombInnOonFamilyPerPersonMOOP                        NaN
# DEHBCombInnOonIndividualMOOP                             NaN
# DEHBDedCombInnOonFamilyPerGroup     per group not applicable
# DEHBDedCombInnOonFamilyPerPerson   per person not applicable
#
# [5 rows x 72 columns]

# %%
ehb('TEHB').head()
# Out:
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                       ...              \
# TEHBCombInnOonFamilyPerGroupMOOP             ...
# TEHBCombInnOonFamilyPerPersonMOOP            ...
# TEHBCombInnOonIndividualMOOP                 ...
# TEHBDedCombInnOonFamilyPerGroup              ...
# TEHBDedCombInnOonFamilyPerPerson             ...
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160019  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005  \
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# PlanId                                        91450AZ0160005
# TEHBCombInnOonFamilyPerGroupMOOP    per group not applicable
# TEHBCombInnOonFamilyPerPersonMOOP  per person not applicable
# TEHBCombInnOonIndividualMOOP                  Not Applicable
# TEHBDedCombInnOonFamilyPerGroup                          NaN
# TEHBDedCombInnOonFamilyPerPerson                         NaN
#
# [5 rows x 72 columns]
