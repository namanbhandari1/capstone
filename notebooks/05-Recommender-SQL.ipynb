# %% [markdown]
# # Similarity of plans
#
# In this notebook, I will ask users to select plan benefits that are most important to them and create a vector based on those selections. This vector object is the primary mechanism of comparison for plans. These vectors can just be thought of as geometrical vectors, and so should have an angle between them. This angle is precisely the quantity which the similarity score we will use, cosine similarity, implicitly measures. Two vectors have a higher similarity score when the angle between them is smaller.
#
# I will compare this user-generated vector with the unique plan vectors available in our `no_dupes` dataframe to analyze their similarity. When we talk about whether or not two plans are similar, we're really talking about the similarity of the vectors.
#
# I use numpy to perform efficient numerical matrix operations and some sorting. I use the tkinter library to obtain user input via a GUI.
#
# # Outcome
#
# This recommender system could be useful to a benefits broker as a proprietary tool used to help clients select a health plan that is best suited to their companies.
#
# This recommender system could also be used by an HR manager at a company to self-select plans based on the features selected in the health plan.
#
# The recommender systems alleviates certain difficulties in selecting plans based on features. Most websites allow users to compare plans on price only. However, the features that are included or excluded from low price plans, as compared to high price plans, may be unclear.

# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity

import pickle
from tabulate import tabulate

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2
# set up connection to database (with username/pw if needed)
engine = create_engine('postgres://postgres:postgres@54.190.31.46:5432/')
# Out:
# /Users/namanbhandari/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# with open ('../pickles/df.pkl', 'rb') as pkl:
#     df = pickle.load(pkl)

# %%
with open ('../pickles/rate_cols.pkl', 'rb') as pkl:
    rate_cols = pickle.load(pkl)
    excl = ['BusinessYear', 'RateEffectiveDate', 'RateExpirationDate', 'RowNumber']
    rate_cols = [col for col in rate_cols if col not in excl]

# %%
# we will use these "excluded" columns in a list comprehension in a later cell
exclude = ['BusinessYear',
'StateCode',
'RateEffectiveDate',
'RateExpirationDate',
'PlanId',
'RatingAreaId',
'Tobacco',
'Age',
'IndividualRate',
'IndividualTobaccoRate',
'Couple',
'PrimarySubscriberAndOneDependent',
'PrimarySubscriberAndTwoDependents',
'PrimarySubscriberAndThreeOrMoreDependents',
'CoupleAndOneDependent',
'CoupleAndTwoDependents',
'CoupleAndThreeOrMoreDependents',
'RowNumber',
'IsNoticeRequiredForPregnancy',
'IsReferralRequiredForSpecialist',
'ChildOnlyOffering',
'WellnessProgramOffered',
'DiseaseManagementProgramsOffered',
'OutOfCountryCoverage',
'NationalNetwork',
'ben_key']

# %% [markdown]
# ## Filter the data
#
# Below, users can filter by a couple of parameters, as follows:
#
# - `'Age'`
# - `'Tobacco User'`
# - `'State'`
#
# Other filters the user can select for include:
#
# - `'IsNoticeRequiredForPregnancy'`: Yes / No / No Preference
# - `'IsReferralRequiredForSpecialist'`: Yes / No / No Preference
# - `'ChildOnlyOffering'`: Allows Child-Only, Allows Adult and Child-Only
# - `'WellnessProgramOffered'`: Yes / No / No Preference
# - `'OutOfCountryCoverage'`: Yes / No
# - `'NationalNetwork'`: Yes / No

# %%
def filter_plans(age, tobacco, state):
    if tobacco == 'yes':
        query = f"""
        SELECT *
        FROM small
        WHERE "StateCode"={state} 
        AND "Age"={age}
        AND "IndividualTobaccoRate" IS NOT NULL
        """
        filtered_df = pd.read_sql(query, con=engine)
    else:
        query = f"""
        SELECT *
        FROM small
        WHERE "StateCode"={state} 
        AND "Age"={age}
        """
        filtered_df = pd.read_sql(query, con=engine)
    return filtered_df

# %% [markdown]
# Below are the additional criteria on which users can filter, with all available choices.

# %%
other_feats = {
'IsNoticeRequiredForPregnancy': [None, 'Yes', 'No'],
'IsReferralRequiredForSpecialist': [None, 'Yes', 'No'],
'ChildOnlyOffering': ['Allows Child-Only', 'Allows Adult and Child-Only'],
'WellnessProgramOffered': [None, 'Yes', 'No'],
'OutOfCountryCoverage': ['Yes', 'No'],
'NationalNetwork': ['No', 'Yes', 'YEs']
}

# %%
def addl_filter(feats = other_feats):
    filtered_df = filter_plans("'30'", "'yes'", "'AZ'")
    for feat in feats:
        filtered_df = filtered_df[filtered_df[feat].isin(feats[feat])]
    return filtered_df

# %% [markdown]
# Below, users can customize to include only those choices they are interested in, and then run the `addl_filter` function and pass `my_feats` as a parameter.

# %%
my_feats = {
'IsNoticeRequiredForPregnancy': [None, 'Yes', 'No'],
'IsReferralRequiredForSpecialist': [None, 'Yes', 'No'],
'ChildOnlyOffering': ['Allows Child-Only', 'Allows Adult and Child-Only'],
'WellnessProgramOffered': [None, 'Yes', 'No'],
'OutOfCountryCoverage': ['Yes', 'No'],
'NationalNetwork': ['No', 'Yes', 'YEs']
}

# %%
df_filt = addl_filter(my_feats)

# %% [markdown]
# ## Filtering by unique plan vectors: `no_dupes`
#
# In a previous notebook, I created a matrix of vectors (called `no_dupes`) in which each vector represented a unique combination of available benefits. No two vectors are the same (however, a particular vector can represent many different types of plans).
#
# Below, I will condense the `no_dupes` matrix to only those plans available based on the filtering performed above.
#
# As you will see, we start off with 215 rows in `no_dupes` (representing 215 unique plan vectors), but after filtering, we are left with far fewer unique plans (the specific amount that remain depends on the filtering criteria from above).

# %%
with open ('../pickles/no_dupes.pkl', 'rb') as pkl:
    no_dupes = pickle.load(pkl)

# %%
no_dupes.shape
# Out:
# (215, 207)

# %%
unique_keys = list(df_filt['ben_key'].unique())

# %%
unique_keys
# Out:
# [94, 17, 21, 214, 24, 77, 71, 68, 19, 8, 101, 6, 156, 26, 78, 76, 7, 157, 86]

# %%
no_dupes = no_dupes[no_dupes.index.isin(unique_keys)]

# %%
no_dupes.shape
# Out:
# (19, 207)

# %% [markdown]
# Below, I am storing the column names and indexes of the filtered dataframe `df_filt` and converting it into a NumPy array for efficient computation. I will use the dictionaries later as a lookup into the NumPy array.

# %%
col_dict = dict(zip(no_dupes.columns, range(len(no_dupes.columns))))

# %%
ind_dict = dict(zip(range(len(no_dupes)), no_dupes.index))

# %%
no_dupes_mat = np.asarray(no_dupes)

# %% [markdown]
# Below, I'm creating a list of benefits that are available for selection based on the `df_filt` from above. This list will be passed into the `tkinter` GUI which will allow users to select from benefits that are actually, verifiably available from the plans they filtered for.

# %%
ben_cols_dum = [col for col in no_dupes if no_dupes[col].sum() != 0]

# %% [markdown]
# ## Generate a unique plan
#
# Using tkinter, Python's inbuilt GUI, I ask users to select the features they would like in their plan, and create a vector based on those selected features. Any benefits that are not selected are treated homogeneously and equal to all other un-selected features, so no information is "lost".

# %%
from tkinter import *
import tkinter as tk

# ----- Section: functions -----

sel_feats = []

def on_keyrelease(event):

    # get text from entry
    value = event.widget.get()
    value = value.strip().lower()

    # get data from test_list
    if value == '':
        data = test_list
    else:
        data = []
        for item in test_list:
            if value in item.lower():
                data.append(item)                

    # update data in listbox
    listbox_update(data)


def listbox_update(data):
    # delete previous data
    l1.delete(0, 'end')

    # sorting data 
    data = sorted(data, key=str.lower)

    # put new data
    for item in data:
        l1.insert('end', item)

def onselect(event):
    selection = l1.curselection()
    for i in selection:
        entry = l1.get(i)
        l2.insert(END, entry)
        print(l1.get(i))
        
def submit(event):
    content = l2.get(0, tk.END)
    for i in content:
        sel_feats.append(i)
    print(sel_feats)

# ----- Section: code -----

test_list = ben_cols_dum

root = Tk()

label = Label(root, text="Type below!")
label.pack(side=TOP)

entry = Entry(root,
             width=40)
entry.pack(side=TOP)
entry.bind('<KeyRelease>', on_keyrelease)

l1 = Listbox(root, 
             selectmode=MULTIPLE, 
             width=40, 
             height=10)
l1.pack(padx=20, pady=20)
listbox_update(test_list)

btn = Button(root, text="Add")
btn.pack()
btn.bind('<Button-1>', onselect)

l2 = Listbox(root, width=40, height=10)
l2.pack(padx=20, pady=20)

btn = Button(root, text="Submit")
btn.pack()
btn.bind('<Button-1>', submit)

root.mainloop()
# Out:
# Allergy Testing
# Chemotherapy
# Clinical Trials
# Cosmetic Surgery
# ['Allergy Testing', 'Chemotherapy', 'Clinical Trials', 'Cosmetic Surgery']

# %%
sel_feats = list(set(sel_feats))

# %%
ben_vec = np.zeros(no_dupes_mat.shape[1])

# %% [markdown]
# Below, I fill in "1s" in my NumPy matrix corresponding to the features selected by the user.

# %%
sel_feats
# Out:
# ['Chemotherapy', 'Allergy Testing', 'Cosmetic Surgery', 'Clinical Trials']

# %%
for benefit in sel_feats:
    ben_vec[col_dict[benefit]] = 1

# %%
ben_vec = np.reshape(ben_vec, (1, -1))

# %%
ben_vec.shape
# Out:
# (1, 207)

# %% [markdown]
# ## Find cosine similarity between `ben_vec` and `no_dupes`

# %%
cos_mat = cosine_similarity(ben_vec, no_dupes_mat)

# %%
i = 0
top_matches = []
for item in cos_mat[0]:
    if item == 0:
        pass
    else:
        top_matches.append([item, ind_dict[i]])
    i += 1
top_matches.sort(reverse=True)

# %% [markdown]
# Below are the plans that best match the user's selected criteria.

# %%
print("Ben_keys most similar to ben_vec:", [b for a, b in top_matches])
# Out:
# Ben_keys most similar to ben_vec: [157, 156, 214, 6, 68, 7, 76, 71, 8, 78, 77, 86]

# %% [markdown]
# ## View plan details
#
# Below, the user can run a couple of functions to view additional details about his select plan and plan variants.

# %%
print("\n", "Using the list below, please find the Index # of the plan variant you would like to view.")
print(tabulate(
    [[top_matches[i][1], top_matches[i][0], i] for i in range(len(top_matches))], 
    ["Plan Variant", "Similarity", "Index #"], 
    tablefmt="grid"
))
# Out:
#  Using the list below, please find the Index # of the plan variant you would like to view.
# +----------------+--------------+-----------+
# |   Plan Variant |   Similarity |   Index # |
# +================+==============+===========+
# |            157 |     0.242536 |         0 |
# +----------------+--------------+-----------+
# |            156 |     0.242536 |         1 |
# +----------------+--------------+-----------+
# |            214 |     0.235702 |         2 |
# +----------------+--------------+-----------+
# |              6 |     0.208013 |         3 |
# +----------------+--------------+-----------+
# |             68 |     0.20226  |         4 |
# +----------------+--------------+-----------+
# |              7 |     0.200446 |         5 |
# +----------------+--------------+-----------+
# |             76 |     0.19696  |         6 |
# +----------------+--------------+-----------+
# |             71 |     0.19696  |         7 |
# +----------------+--------------+-----------+
# |              8 |     0.19696  |         8 |
# +----------------+--------------+-----------+
# |             78 |     0.195283 |         9 |
# +----------------+--------------+-----------+
# |             77 |     0.195283 |        10 |
# +----------------+--------------+-----------+
# |             86 |     0.1905   |        11 |
# +----------------+--------------+-----------+

# %% [markdown]
# Below, please enter your selected Index # in the `covered_feats` function, which will allow you to see the features that are covered in the plan variant:

# %%
def covered_feats(index):
    # Get covered features in dataframe
    feat_coverage = no_dupes[no_dupes.index == top_matches[index][1]][sel_feats].head(10)

    # Plot the features
    x = list(feat_coverage.columns)
    coverage = [1 if feat_coverage[i].sum() > 0 else 0.01 for i in list(feat_coverage.columns)]
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'g']

    x_pos = [i for i, _ in enumerate(x)]

    plt.barh(x_pos, coverage, color='green')
    plt.ylabel("Benefit Name")
    plt.title("Feature availability in selected plan variant")

    plt.yticks(x_pos, x)
    plt.xticks(np.arange(2), ('Not Available', 'Available'))

    plt.show()
    return feat_coverage
feat_coverage = covered_feats(3)

# %% [markdown]
# Below, please enter the index number in the `matching_plans` function corresponding to the plan variant you would like to view. This function will then show you all the available plans in that plan variant.

# %%
def matching_plans(index):
    matches = df_filt[df_filt['ben_key'] == top_matches[index][1]][rate_cols].dropna(axis=1)
    print("\n", "There are", matches.shape[0], """plans available for selection. 
    Showing top 5, sorted by lowest price:""")
    return matches
matches = matching_plans(3).sort_values('IndividualRate')
matches.head()
# Out:
#  There are 32 plans available for selection.
#     Showing top 5, sorted by lowest price:
#      StateCode          PlanId   RatingAreaId                        Tobacco  \
# 757         AZ  70239AZ0010079  Rating Area 4  Tobacco User/Non-Tobacco User
# 1037        AZ  70239AZ0010072  Rating Area 5  Tobacco User/Non-Tobacco User
# 1039        AZ  70239AZ0010075  Rating Area 4  Tobacco User/Non-Tobacco User
# 1038        AZ  70239AZ0010074  Rating Area 6  Tobacco User/Non-Tobacco User
# 756         AZ  70239AZ0010078  Rating Area 4  Tobacco User/Non-Tobacco User
#
#      Age  IndividualRate  IndividualTobaccoRate
# 757   30          108.64                 110.82
# 1037  30          126.21                 128.74
# 1039  30          132.20                 134.85
# 1038  30          135.19                 137.89
# 756   30          156.41                 159.54

# %%
print("The average price of plans in each rating area is shown below:")
matches.groupby('RatingAreaId').mean().dropna().sort_values('IndividualRate')
# Out:
# The average price of plans in each rating area is shown below:
#                IndividualRate  IndividualTobaccoRate
# RatingAreaId
# Rating Area 4        176.4675              179.99875
# Rating Area 5        194.7700              198.66750
# Rating Area 6        208.6125              212.78250
# Rating Area 1        264.8725              270.17000

# %% [markdown]
# The below shows the user the price by `'RatingAreaId'` - with some areas in the state more expensive than others.

# %%
matches[matches['RatingAreaId'] == 'Rating Area 4']
# Out:
#      StateCode          PlanId   RatingAreaId                        Tobacco  \
# 757         AZ  70239AZ0010079  Rating Area 4  Tobacco User/Non-Tobacco User
# 1039        AZ  70239AZ0010075  Rating Area 4  Tobacco User/Non-Tobacco User
# 756         AZ  70239AZ0010078  Rating Area 4  Tobacco User/Non-Tobacco User
# 758         AZ  70239AZ0010080  Rating Area 4  Tobacco User/Non-Tobacco User
# 1041        AZ  70239AZ0010077  Rating Area 4  Tobacco User/Non-Tobacco User
# 1032        AZ  70239AZ0010067  Rating Area 4  Tobacco User/Non-Tobacco User
# 1031        AZ  70239AZ0010066  Rating Area 4  Tobacco User/Non-Tobacco User
# 1040        AZ  70239AZ0010076  Rating Area 4  Tobacco User/Non-Tobacco User
#
#      Age  IndividualRate  IndividualTobaccoRate
# 757   30          108.64                 110.82
# 1039  30          132.20                 134.85
# 756   30          156.41                 159.54
# 758   30          183.76                 187.43
# 1041  30          186.82                 190.56
# 1032  30          198.58                 202.55
# 1031  30          222.45                 226.90
# 1040  30          222.88                 227.34

# %%
## Figure out cost of plans like mine in other states

# %% [markdown]
# Now, we we load in data from `attributes.pkl` and save it as `attributes`. This file contains plan variant-level data on maximum out of pocket payments, deductibles, health savings account (HSA) eligibility, formulary ID, and other plan attributes.

# %%
with open ('../pickles/attributes.pkl', 'rb') as pkl:
    attributes = pickle.load(pkl)

# %%
list(attributes.columns)
# Out:
# ['AVCalculatorOutputNumber',
#  'BeginPrimaryCareCostSharingAfterNumberOfVisits',
#  'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays',
#  'BenefitPackageId',
#  'BusinessYear',
#  'CSRVariationType',
#  'ChildOnlyOffering',
#  'ChildOnlyPlanId',
#  'CompositeRatingOffered',
#  'DEHBCombInnOonFamilyMOOP',
#  'DEHBCombInnOonFamilyPerGroupMOOP',
#  'DEHBCombInnOonFamilyPerPersonMOOP',
#  'DEHBCombInnOonIndividualMOOP',
#  'DEHBDedCombInnOonFamily',
#  'DEHBDedCombInnOonFamilyPerGroup',
#  'DEHBDedCombInnOonFamilyPerPerson',
#  'DEHBDedCombInnOonIndividual',
#  'DEHBDedInnTier1Coinsurance',
#  'DEHBDedInnTier1Family',
#  'DEHBDedInnTier1FamilyPerGroup',
#  'DEHBDedInnTier1FamilyPerPerson',
#  'DEHBDedInnTier1Individual',
#  'DEHBDedInnTier2Coinsurance',
#  'DEHBDedInnTier2Family',
#  'DEHBDedInnTier2FamilyPerGroup',
#  'DEHBDedInnTier2FamilyPerPerson',
#  'DEHBDedInnTier2Individual',
#  'DEHBDedOutOfNetFamily',
#  'DEHBDedOutOfNetFamilyPerGroup',
#  'DEHBDedOutOfNetFamilyPerPerson',
#  'DEHBDedOutOfNetIndividual',
#  'DEHBInnTier1FamilyMOOP',
#  'DEHBInnTier1FamilyPerGroupMOOP',
#  'DEHBInnTier1FamilyPerPersonMOOP',
#  'DEHBInnTier1IndividualMOOP',
#  'DEHBInnTier2FamilyMOOP',
#  'DEHBInnTier2FamilyPerGroupMOOP',
#  'DEHBInnTier2FamilyPerPersonMOOP',
#  'DEHBInnTier2IndividualMOOP',
#  'DEHBOutOfNetFamilyMOOP',
#  'DEHBOutOfNetFamilyPerGroupMOOP',
#  'DEHBOutOfNetFamilyPerPersonMOOP',
#  'DEHBOutOfNetIndividualMOOP',
#  'DentalOnlyPlan',
#  'DiseaseManagementProgramsOffered',
#  'EHBPediatricDentalApportionmentQuantity',
#  'EHBPercentPremiumS4',
#  'EHBPercentTotalPremium',
#  'FirstTierUtilization',
#  'FormularyId',
#  'FormularyURL',
#  'HIOSProductId',
#  'HPID',
#  'HSAOrHRAEmployerContribution',
#  'HSAOrHRAEmployerContributionAmount',
#  'ImportDate',
#  'IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee',
#  'InpatientCopaymentMaximumDays',
#  'IsGuaranteedRate',
#  'IsHSAEligible',
#  'IsNewPlan',
#  'IsNoticeRequiredForPregnancy',
#  'IsReferralRequiredForSpecialist',
#  'IssuerActuarialValue',
#  'IssuerId',
#  'IssuerId2',
#  'MEHBCombInnOonFamilyMOOP',
#  'MEHBCombInnOonFamilyPerGroupMOOP',
#  'MEHBCombInnOonFamilyPerPersonMOOP',
#  'MEHBCombInnOonIndividualMOOP',
#  'MEHBDedCombInnOonFamily',
#  'MEHBDedCombInnOonFamilyPerGroup',
#  'MEHBDedCombInnOonFamilyPerPerson',
#  'MEHBDedCombInnOonIndividual',
#  'MEHBDedInnTier1Coinsurance',
#  'MEHBDedInnTier1Family',
#  'MEHBDedInnTier1FamilyPerGroup',
#  'MEHBDedInnTier1FamilyPerPerson',
#  'MEHBDedInnTier1Individual',
#  'MEHBDedInnTier2Coinsurance',
#  'MEHBDedInnTier2Family',
#  'MEHBDedInnTier2FamilyPerGroup',
#  'MEHBDedInnTier2FamilyPerPerson',
#  'MEHBDedInnTier2Individual',
#  'MEHBDedOutOfNetFamily',
#  'MEHBDedOutOfNetFamilyPerGroup',
#  'MEHBDedOutOfNetFamilyPerPerson',
#  'MEHBDedOutOfNetIndividual',
#  'MEHBInnTier1FamilyMOOP',
#  'MEHBInnTier1FamilyPerGroupMOOP',
#  'MEHBInnTier1FamilyPerPersonMOOP',
#  'MEHBInnTier1IndividualMOOP',
#  'MEHBInnTier2FamilyMOOP',
#  'MEHBInnTier2FamilyPerGroupMOOP',
#  'MEHBInnTier2FamilyPerPersonMOOP',
#  'MEHBInnTier2IndividualMOOP',
#  'MEHBOutOfNetFamilyMOOP',
#  'MEHBOutOfNetFamilyPerGroupMOOP',
#  'MEHBOutOfNetFamilyPerPersonMOOP',
#  'MEHBOutOfNetIndividualMOOP',
#  'MarketCoverage',
#  'MedicalDrugDeductiblesIntegrated',
#  'MedicalDrugMaximumOutofPocketIntegrated',
#  'MetalLevel',
#  'MultipleInNetworkTiers',
#  'NationalNetwork',
#  'NetworkId',
#  'OutOfCountryCoverage',
#  'OutOfCountryCoverageDescription',
#  'OutOfServiceAreaCoverage',
#  'OutOfServiceAreaCoverageDescription',
#  'PlanBrochure',
#  'PlanEffictiveDate',
#  'PlanExpirationDate',
#  'PlanLevelExclusions',
#  'PlanMarketingName',
#  'PlanType',
#  'QHPNonQHPTypeId',
#  'RowNumber',
#  'SBCHavingDiabetesCoinsurance',
#  'SBCHavingDiabetesCopayment',
#  'SBCHavingDiabetesDeductible',
#  'SBCHavingDiabetesLimit',
#  'SBCHavingaBabyCoinsurance',
#  'SBCHavingaBabyCopayment',
#  'SBCHavingaBabyDeductible',
#  'SBCHavingaBabyLimit',
#  'SecondTierUtilization',
#  'ServiceAreaId',
#  'SourceName',
#  'SpecialistRequiringReferral',
#  'SpecialtyDrugMaximumCoinsurance',
#  'PlanId',
#  'StateCode',
#  'StateCode2',
#  'TEHBCombInnOonFamilyMOOP',
#  'TEHBCombInnOonFamilyPerGroupMOOP',
#  'TEHBCombInnOonFamilyPerPersonMOOP',
#  'TEHBCombInnOonIndividualMOOP',
#  'TEHBDedCombInnOonFamily',
#  'TEHBDedCombInnOonFamilyPerGroup',
#  'TEHBDedCombInnOonFamilyPerPerson',
#  'TEHBDedCombInnOonIndividual',
#  'TEHBDedInnTier1Coinsurance',
#  'TEHBDedInnTier1Family',
#  'TEHBDedInnTier1FamilyPerGroup',
#  'TEHBDedInnTier1FamilyPerPerson',
#  'TEHBDedInnTier1Individual',
#  'TEHBDedInnTier2Coinsurance',
#  'TEHBDedInnTier2Family',
#  'TEHBDedInnTier2FamilyPerGroup',
#  'TEHBDedInnTier2FamilyPerPerson',
#  'TEHBDedInnTier2Individual',
#  'TEHBDedOutOfNetFamily',
#  'TEHBDedOutOfNetFamilyPerGroup',
#  'TEHBDedOutOfNetFamilyPerPerson',
#  'TEHBDedOutOfNetIndividual',
#  'TEHBInnTier1FamilyMOOP',
#  'TEHBInnTier1FamilyPerGroupMOOP',
#  'TEHBInnTier1FamilyPerPersonMOOP',
#  'TEHBInnTier1IndividualMOOP',
#  'TEHBInnTier2FamilyMOOP',
#  'TEHBInnTier2FamilyPerGroupMOOP',
#  'TEHBInnTier2FamilyPerPersonMOOP',
#  'TEHBInnTier2IndividualMOOP',
#  'TEHBOutOfNetFamilyMOOP',
#  'TEHBOutOfNetFamilyPerGroupMOOP',
#  'TEHBOutOfNetFamilyPerPersonMOOP',
#  'TEHBOutOfNetIndividualMOOP',
#  'TIN',
#  'URLForEnrollmentPayment',
#  'URLForSummaryofBenefitsCoverage',
#  'UniquePlanDesign',
#  'VersionNum',
#  'WellnessProgramOffered']

# %%
attr_exclude = [
    'AVCalculatorOutputNumber',
    'BenefitPackageId',
    'BusinessYear',
    'CompositeRatingOffered',
    'FormularyId',
    'HIOSProductId',
    'HPID',
    'ImportDate',
    'IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee',
    'IssuerId',
    'IssuerId2',
    'NetworkId',
    'SourceName',
    'QHPNonQHPTypeId',
    'PlanEffictiveDate',
    'PlanExpirationDate',
    'RowNumber',
    'ServiceAreaId',
    'TIN',
    'VersionNum',
    'StateCode2'
]
attribute_cols = [col for col in list(attributes.columns) if col not in attr_exclude]

# %%
other_feats_key = list(other_feats.keys())

# %%
other_feats_key.append('PlanId')

# %%
def view_details(plan, view_cols=other_feats_key):
    details = attributes[attributes['PlanId'] == plan][view_cols].T.dropna()
    return details

# %% [markdown]
# Now that we have the columns of interest from `attributes`, we can run a cell to view all attributes of interest for each plan in our match.

# %%
compare = view_details(matches['PlanId'].iloc[0], view_cols=attribute_cols)
for plan in matches['PlanId'][1:]:
    interim = pd.merge(compare, 
             view_details(plan, attribute_cols),
             left_index=True,
             right_index=True)
    compare = interim
compare = compare.T.set_index('PlanId').T
compare
# Out:
# PlanId                                                                                 70239AZ0010079  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                           Health Choice Value Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010072  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010075  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010074  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010078  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                    Standard Bronze Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                                     Bronze
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                          Health Choice Value Bronze
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010071  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010070  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                     $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $6850 per person
# TEHBCombInnOonIndividualMOOP                                                                  $6,850
# TEHBDedCombInnOonFamilyPerGroup                                                      $13700 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $6850 per person
# TEHBDedCombInnOonIndividual                                                                   $6,850
# TEHBDedInnTier1Coinsurance                                                                         0%
# TEHBDedInnTier1FamilyPerGroup                                                        $13700 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $6850 per person
# TEHBDedInnTier1Individual                                                                     $6,850
# TEHBDedOutOfNetFamilyPerGroup                                                        $13700 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $6850 per person
# TEHBDedOutOfNetIndividual                                                                     $6,850
# TEHBInnTier1FamilyPerGroupMOOP                                                       $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $6850 per person
# TEHBInnTier1IndividualMOOP                                                                    $6,850
# TEHBOutOfNetFamilyPerGroupMOOP                                                       $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $6850 per person
# TEHBOutOfNetIndividualMOOP                                                                    $6,850
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010069  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  3
# CSRVariationType                                              Standard Catastrophic Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                               Catastrophic
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                       Health Choice Essential Basic
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                        $0
# SBCHavingDiabetesDeductible                                                                   $6,850
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                         $0
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $6,850
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# ...
# SBCHavingDiabetesCopayment                                                                      $220
# SBCHavingDiabetesDeductible                                                                   $1,500
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                     $1,208
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $1,500
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                      $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $4500 per person
# TEHBCombInnOonIndividualMOOP                                                                  $4,500
# TEHBDedCombInnOonFamilyPerGroup                                                       $3000 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $1500 per person
# TEHBDedCombInnOonIndividual                                                                   $1,500
# TEHBDedInnTier1Coinsurance                                                                        20%
# TEHBDedInnTier1FamilyPerGroup                                                         $3000 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $1500 per person
# TEHBDedInnTier1Individual                                                                     $1,500
# TEHBDedOutOfNetFamilyPerGroup                                                         $3000 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $1500 per person
# TEHBDedOutOfNetIndividual                                                                     $1,500
# TEHBInnTier1FamilyPerGroupMOOP                                                        $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4500 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,500
# TEHBOutOfNetFamilyPerGroupMOOP                                                        $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $4500 per person
# TEHBOutOfNetIndividualMOOP                                                                    $4,500
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010054  \
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                        Health Choice Essential Gold
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                      $220
# SBCHavingDiabetesDeductible                                                                   $1,500
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                     $1,208
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $1,500
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                      $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $4500 per person
# TEHBCombInnOonIndividualMOOP                                                                  $4,500
# TEHBDedCombInnOonFamilyPerGroup                                                       $3000 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $1500 per person
# TEHBDedCombInnOonIndividual                                                                   $1,500
# TEHBDedInnTier1Coinsurance                                                                        20%
# TEHBDedInnTier1FamilyPerGroup                                                         $3000 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $1500 per person
# TEHBDedInnTier1Individual                                                                     $1,500
# TEHBDedOutOfNetFamilyPerGroup                                                         $3000 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $1500 per person
# TEHBDedOutOfNetIndividual                                                                     $1,500
# TEHBInnTier1FamilyPerGroupMOOP                                                        $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4500 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,500
# TEHBOutOfNetFamilyPerGroupMOOP                                                        $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $4500 per person
# TEHBOutOfNetIndividualMOOP                                                                    $4,500
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# PlanId                                                                                 70239AZ0010045
# BeginPrimaryCareCostSharingAfterNumberOfVisits                                                      0
# BeginPrimaryCareDeductibleCoinsuranceAfterNumbe...                                                  0
# CSRVariationType                                                      Standard Gold Off Exchange Plan
# ChildOnlyOffering                                                         Allows Adult and Child-Only
# DentalOnlyPlan                                                                                     No
# EHBPercentTotalPremium                                                                              1
# FirstTierUtilization                                                                             100%
# FormularyURL                                        http://www.healthchoiceessential.com/members/r...
# InpatientCopaymentMaximumDays                                                                       0
# IsHSAEligible                                                                                      No
# IsNewPlan                                                                                         New
# IsNoticeRequiredForPregnancy                                                                       No
# IsReferralRequiredForSpecialist                                                                   Yes
# MarketCoverage                                                                             Individual
# MedicalDrugDeductiblesIntegrated                                                                  Yes
# MedicalDrugMaximumOutofPocketIntegrated                                                           Yes
# MetalLevel                                                                                       Gold
# MultipleInNetworkTiers                                                                             No
# NationalNetwork                                                                                    No
# OutOfCountryCoverage                                                                              Yes
# OutOfCountryCoverageDescription                     Out of Country Coverage is covered for any exp...
# OutOfServiceAreaCoverage                                                                          Yes
# OutOfServiceAreaCoverageDescription                 Out of Service Area Coverage is covered for an...
# PlanBrochure                                             http://www.healthchoiceessential.com/members
# PlanMarketingName                                                        Health Choice Essential Gold
# PlanType                                                                                          HMO
# SBCHavingDiabetesCoinsurance                                                                      $0
# SBCHavingDiabetesCopayment                                                                      $220
# SBCHavingDiabetesDeductible                                                                   $1,500
# SBCHavingDiabetesLimit                                                                            $0
# SBCHavingaBabyCoinsurance                                                                     $1,208
# SBCHavingaBabyCopayment                                                                           $0
# SBCHavingaBabyDeductible                                                                      $1,500
# SBCHavingaBabyLimit                                                                               $0
# SpecialistRequiringReferral                         All providers other than Family Practice, Pedi...
# StateCode                                                                                          AZ
# TEHBCombInnOonFamilyPerGroupMOOP                                                      $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP                                                    $4500 per person
# TEHBCombInnOonIndividualMOOP                                                                  $4,500
# TEHBDedCombInnOonFamilyPerGroup                                                       $3000 per group
# TEHBDedCombInnOonFamilyPerPerson                                                     $1500 per person
# TEHBDedCombInnOonIndividual                                                                   $1,500
# TEHBDedInnTier1Coinsurance                                                                        20%
# TEHBDedInnTier1FamilyPerGroup                                                         $3000 per group
# TEHBDedInnTier1FamilyPerPerson                                                       $1500 per person
# TEHBDedInnTier1Individual                                                                     $1,500
# TEHBDedOutOfNetFamilyPerGroup                                                         $3000 per group
# TEHBDedOutOfNetFamilyPerPerson                                                       $1500 per person
# TEHBDedOutOfNetIndividual                                                                     $1,500
# TEHBInnTier1FamilyPerGroupMOOP                                                        $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP                                                      $4500 per person
# TEHBInnTier1IndividualMOOP                                                                    $4,500
# TEHBOutOfNetFamilyPerGroupMOOP                                                        $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP                                                      $4500 per person
# TEHBOutOfNetIndividualMOOP                                                                    $4,500
# URLForEnrollmentPayment                             https://www.healthchoiceessential.com/Enrollme...
# URLForSummaryofBenefitsCoverage                     http://www.healthchoiceessential.com/members/m...
# UniquePlanDesign                                                                                   No
# WellnessProgramOffered                                                                             No
#
# [59 rows x 32 columns]

# %%
compare[compare.index.isin(['TEHBCombInnOonFamilyPerGroupMOOP',
'TEHBCombInnOonFamilyPerPersonMOOP',
'TEHBCombInnOonIndividualMOOP',
'TEHBDedCombInnOonFamilyPerGroup',
'TEHBDedCombInnOonFamilyPerPerson',
'TEHBDedCombInnOonIndividual',
'TEHBDedInnTier1Coinsurance',
'TEHBDedInnTier1FamilyPerGroup',
'TEHBDedInnTier1FamilyPerPerson',
'TEHBDedInnTier1Individual',
'TEHBDedOutOfNetFamilyPerGroup',
'TEHBDedOutOfNetFamilyPerPerson',
'TEHBDedOutOfNetIndividual',
'TEHBInnTier1FamilyPerGroupMOOP',
'TEHBInnTier1FamilyPerPersonMOOP',
'TEHBInnTier1IndividualMOOP',
'TEHBOutOfNetFamilyPerGroupMOOP',
'TEHBOutOfNetFamilyPerPersonMOOP',
'TEHBOutOfNetIndividualMOOP'])]
# Out:
# PlanId                               70239AZ0010079    70239AZ0010072  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup    $13700 per group  $13700 per group
# TEHBDedCombInnOonFamilyPerPerson   $6850 per person  $6850 per person
# TEHBDedCombInnOonIndividual                 $6,850            $6,850
# TEHBDedInnTier1Coinsurance                       0%                0%
# TEHBDedInnTier1FamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedInnTier1FamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedInnTier1Individual                   $6,850            $6,850
# TEHBDedOutOfNetFamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedOutOfNetFamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedOutOfNetIndividual                   $6,850            $6,850
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                               70239AZ0010075    70239AZ0010074  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup    $13700 per group  $13700 per group
# TEHBDedCombInnOonFamilyPerPerson   $6850 per person  $6850 per person
# TEHBDedCombInnOonIndividual                 $6,850            $6,850
# TEHBDedInnTier1Coinsurance                       0%                0%
# TEHBDedInnTier1FamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedInnTier1FamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedInnTier1Individual                   $6,850            $6,850
# TEHBDedOutOfNetFamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedOutOfNetFamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedOutOfNetIndividual                   $6,850            $6,850
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                               70239AZ0010078    70239AZ0010071  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup    $13700 per group  $13700 per group
# TEHBDedCombInnOonFamilyPerPerson   $6850 per person  $6850 per person
# TEHBDedCombInnOonIndividual                 $6,850            $6,850
# TEHBDedInnTier1Coinsurance                       0%                0%
# TEHBDedInnTier1FamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedInnTier1FamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedInnTier1Individual                   $6,850            $6,850
# TEHBDedOutOfNetFamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedOutOfNetFamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedOutOfNetIndividual                   $6,850            $6,850
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                               70239AZ0010070    70239AZ0010069  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup    $13700 per group  $13700 per group
# TEHBDedCombInnOonFamilyPerPerson   $6850 per person  $6850 per person
# TEHBDedCombInnOonIndividual                 $6,850            $6,850
# TEHBDedInnTier1Coinsurance                       0%                0%
# TEHBDedInnTier1FamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedInnTier1FamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedInnTier1Individual                   $6,850            $6,850
# TEHBDedOutOfNetFamilyPerGroup      $13700 per group  $13700 per group
# TEHBDedOutOfNetFamilyPerPerson     $6850 per person  $6850 per person
# TEHBDedOutOfNetIndividual                   $6,850            $6,850
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                               70239AZ0010068    70239AZ0010080  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup    $13700 per group   $6200 per group
# TEHBDedCombInnOonFamilyPerPerson   $6850 per person  $3100 per person
# TEHBDedCombInnOonIndividual                 $6,850            $3,100
# TEHBDedInnTier1Coinsurance                       0%               20%
# TEHBDedInnTier1FamilyPerGroup      $13700 per group   $6200 per group
# TEHBDedInnTier1FamilyPerPerson     $6850 per person  $3100 per person
# TEHBDedInnTier1Individual                   $6,850            $3,100
# TEHBDedOutOfNetFamilyPerGroup      $13700 per group   $6200 per group
# TEHBDedOutOfNetFamilyPerPerson     $6850 per person  $3100 per person
# TEHBDedOutOfNetIndividual                   $6,850            $3,100
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                                   ...           70239AZ0010053  \
# TEHBCombInnOonFamilyPerGroupMOOP         ...         $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP        ...         $6850 per person
# TEHBCombInnOonIndividualMOOP             ...                  $6,850
# TEHBDedCombInnOonFamilyPerGroup          ...         $13700 per group
# TEHBDedCombInnOonFamilyPerPerson         ...         $6850 per person
# TEHBDedCombInnOonIndividual              ...                  $6,850
# TEHBDedInnTier1Coinsurance               ...                       0%
# TEHBDedInnTier1FamilyPerGroup            ...         $13700 per group
# TEHBDedInnTier1FamilyPerPerson           ...         $6850 per person
# TEHBDedInnTier1Individual                ...                  $6,850
# TEHBDedOutOfNetFamilyPerGroup            ...         $13700 per group
# TEHBDedOutOfNetFamilyPerPerson           ...         $6850 per person
# TEHBDedOutOfNetIndividual                ...                  $6,850
# TEHBInnTier1FamilyPerGroupMOOP           ...         $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP          ...         $6850 per person
# TEHBInnTier1IndividualMOOP               ...                  $6,850
# TEHBOutOfNetFamilyPerGroupMOOP           ...         $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP          ...         $6850 per person
# TEHBOutOfNetIndividualMOOP               ...                  $6,850
#
# PlanId                               70239AZ0010063    70239AZ0010052  \
# TEHBCombInnOonFamilyPerGroupMOOP    $9000 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $4500 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $4,500            $6,850
# TEHBDedCombInnOonFamilyPerGroup     $3000 per group   $5000 per group
# TEHBDedCombInnOonFamilyPerPerson   $1500 per person  $2500 per person
# TEHBDedCombInnOonIndividual                 $1,500            $2,500
# TEHBDedInnTier1Coinsurance                      20%               20%
# TEHBDedInnTier1FamilyPerGroup       $3000 per group   $5000 per group
# TEHBDedInnTier1FamilyPerPerson     $1500 per person  $2500 per person
# TEHBDedInnTier1Individual                   $1,500            $2,500
# TEHBDedOutOfNetFamilyPerGroup       $3000 per group   $5000 per group
# TEHBDedOutOfNetFamilyPerPerson     $1500 per person  $2500 per person
# TEHBDedOutOfNetIndividual                   $1,500            $2,500
# TEHBInnTier1FamilyPerGroupMOOP      $9000 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $4500 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $4,500            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP      $9000 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $4500 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $4,500            $6,850
#
# PlanId                               70239AZ0010049    70239AZ0010046  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group  $13700 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $6850 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $6,850
# TEHBDedCombInnOonFamilyPerGroup     $5000 per group   $5000 per group
# TEHBDedCombInnOonFamilyPerPerson   $2500 per person  $2500 per person
# TEHBDedCombInnOonIndividual                 $2,500            $2,500
# TEHBDedInnTier1Coinsurance                      20%               20%
# TEHBDedInnTier1FamilyPerGroup       $5000 per group   $5000 per group
# TEHBDedInnTier1FamilyPerPerson     $2500 per person  $2500 per person
# TEHBDedInnTier1Individual                   $2,500            $2,500
# TEHBDedOutOfNetFamilyPerGroup       $5000 per group   $5000 per group
# TEHBDedOutOfNetFamilyPerPerson     $2500 per person  $2500 per person
# TEHBDedOutOfNetIndividual                   $2,500            $2,500
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $6,850
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group  $13700 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $6850 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $6,850
#
# PlanId                               70239AZ0010055    70239AZ0010051  \
# TEHBCombInnOonFamilyPerGroupMOOP   $13700 per group   $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $6850 per person  $4500 per person
# TEHBCombInnOonIndividualMOOP                $6,850            $4,500
# TEHBDedCombInnOonFamilyPerGroup     $5000 per group   $3000 per group
# TEHBDedCombInnOonFamilyPerPerson   $2500 per person  $1500 per person
# TEHBDedCombInnOonIndividual                 $2,500            $1,500
# TEHBDedInnTier1Coinsurance                      20%               20%
# TEHBDedInnTier1FamilyPerGroup       $5000 per group   $3000 per group
# TEHBDedInnTier1FamilyPerPerson     $2500 per person  $1500 per person
# TEHBDedInnTier1Individual                   $2,500            $1,500
# TEHBDedOutOfNetFamilyPerGroup       $5000 per group   $3000 per group
# TEHBDedOutOfNetFamilyPerPerson     $2500 per person  $1500 per person
# TEHBDedOutOfNetIndividual                   $2,500            $1,500
# TEHBInnTier1FamilyPerGroupMOOP     $13700 per group   $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP    $6850 per person  $4500 per person
# TEHBInnTier1IndividualMOOP                  $6,850            $4,500
# TEHBOutOfNetFamilyPerGroupMOOP     $13700 per group   $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $6850 per person  $4500 per person
# TEHBOutOfNetIndividualMOOP                  $6,850            $4,500
#
# PlanId                               70239AZ0010048    70239AZ0010054  \
# TEHBCombInnOonFamilyPerGroupMOOP    $9000 per group   $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $4500 per person  $4500 per person
# TEHBCombInnOonIndividualMOOP                $4,500            $4,500
# TEHBDedCombInnOonFamilyPerGroup     $3000 per group   $3000 per group
# TEHBDedCombInnOonFamilyPerPerson   $1500 per person  $1500 per person
# TEHBDedCombInnOonIndividual                 $1,500            $1,500
# TEHBDedInnTier1Coinsurance                      20%               20%
# TEHBDedInnTier1FamilyPerGroup       $3000 per group   $3000 per group
# TEHBDedInnTier1FamilyPerPerson     $1500 per person  $1500 per person
# TEHBDedInnTier1Individual                   $1,500            $1,500
# TEHBDedOutOfNetFamilyPerGroup       $3000 per group   $3000 per group
# TEHBDedOutOfNetFamilyPerPerson     $1500 per person  $1500 per person
# TEHBDedOutOfNetIndividual                   $1,500            $1,500
# TEHBInnTier1FamilyPerGroupMOOP      $9000 per group   $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP    $4500 per person  $4500 per person
# TEHBInnTier1IndividualMOOP                  $4,500            $4,500
# TEHBOutOfNetFamilyPerGroupMOOP      $9000 per group   $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $4500 per person  $4500 per person
# TEHBOutOfNetIndividualMOOP                  $4,500            $4,500
#
# PlanId                               70239AZ0010045
# TEHBCombInnOonFamilyPerGroupMOOP    $9000 per group
# TEHBCombInnOonFamilyPerPersonMOOP  $4500 per person
# TEHBCombInnOonIndividualMOOP                $4,500
# TEHBDedCombInnOonFamilyPerGroup     $3000 per group
# TEHBDedCombInnOonFamilyPerPerson   $1500 per person
# TEHBDedCombInnOonIndividual                 $1,500
# TEHBDedInnTier1Coinsurance                      20%
# TEHBDedInnTier1FamilyPerGroup       $3000 per group
# TEHBDedInnTier1FamilyPerPerson     $1500 per person
# TEHBDedInnTier1Individual                   $1,500
# TEHBDedOutOfNetFamilyPerGroup       $3000 per group
# TEHBDedOutOfNetFamilyPerPerson     $1500 per person
# TEHBDedOutOfNetIndividual                   $1,500
# TEHBInnTier1FamilyPerGroupMOOP      $9000 per group
# TEHBInnTier1FamilyPerPersonMOOP    $4500 per person
# TEHBInnTier1IndividualMOOP                  $4,500
# TEHBOutOfNetFamilyPerGroupMOOP      $9000 per group
# TEHBOutOfNetFamilyPerPersonMOOP    $4500 per person
# TEHBOutOfNetIndividualMOOP                  $4,500
#
# [19 rows x 32 columns]
